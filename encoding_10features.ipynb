# %%
global nop, non
from pandas import DataFrame
from pandas import Series
#from keras.utils import np_utils
from tensorflow.keras.utils import to_categorical
import os
import numpy as np
import pandas as pd

# %%
def acf(list30):  # acl,aal
    # import pandas as pd
    # wt.write(time.strftime( ISOTIMEFORMAT, time.localtime( time.time() ) )+':acf00'+'\n')
    global acl, aal, acn, aan, acsl, aasl
    pos = DataFrame(list30)
    all_ = pos
    # with open('../aaindex1.txt', 'r') as fout:
    #    line=fout.readline()
    #    line=line.rstrip()[5:]
    #    aalist=line.split('\t')
    ll, j = 0, 0
    na = {}  # AAindex字典：特征->氨基酸对应值
    vvl = []  # top10特征名字列表,用于在na字典中搜索
    with open('./results/top10.txt', 'r') as fout:
        line = fout.readline()
        line = line.rstrip()[5:]
        aalist = line.split('\t')  # aa名称列表
        for line in fout:
            ll = ll + 1
            line = line.rstrip()
            na[line.split('\t')[0]] = line.split('\t')[1:]
            vvl.append(line.split('\t')[0])

    # wt.write(time.strftime( ISOTIMEFORMAT, time.localtime( time.time() ) )+':acf100')
    # with open('../aaindex1.txt', 'r') as fout:
    #    line=fout.readline()
    #    line=line.rstrip()[5:]
    #    aalist=line.split('\t')
    #    for line in fout:
    #        j=j+1
    #        line=line.rstrip()
    #        na[j]=line.split('\t')[1:]
    # vvl1.sort(reverse=True)
    # vvl = []
    # con=range(11,31)
    # ww=open('top10.txt','w')
    # ww.write('name\t'+'\t'.join(aalist)+'\n')
    # for co in (range(30)):
    #     if co + 1 in con:
    #         llo = 0
    #     else:
    #         vvl.append(vvl1[co])
    #         ww.write(str(vvlist[vvl1[co]])+'\t'+'\t'.join(na[vvlist[vvl1[co]]])+'\n')

    def doc2num1(ss):
        sss, AAindex_Encode = [], []
        ss = ss.replace('*', '0')
        ss = ss.replace('X', '0')
        ss = ss.replace('B', '0')
        ss = ss.replace('U', '0')
        for k in vvl:
            s = list(ss)
            for i, ii in enumerate(aalist):
                s = [(na[k][i]) if x == ii else x for x in s]
            s = [float(x) for x in s]
            sss = sss + s
        return sss

    def doc2num(ss):  # ss=all_[0]=usp序列
        # ss=ss[20:-20]
        AAindex_Encode = []
        ss = ss.replace('*', '0')
        ss = ss.replace('X', '0')
        ss = ss.replace('B', '0')
        ss = ss.replace('U', '0')
        for k in vvl:
            s = list(ss)  # 将ss中的序列从dataframe转化为list存在s中
            for i, ii in enumerate(aalist):  # enumerate枚举，i是索引，ii是值：此处，i是aa名称的索引，ii是aa名称
                s = [(na[k][i]) if x == ii else x for x in s]  # k:vvl（特征） + i:aalist（aa） 一一对应
            s = [float(x) for x in s]
            AAindex_Encode.append(s)
        ACF_Encode = np.zeros((np.array(AAindex_Encode).shape[0], np.array(AAindex_Encode).shape[1]))
        for i, seq in enumerate(AAindex_Encode):
            for k, kv in enumerate(ss):
                sumValue = 0
                for j in range(0, len(seq) - k):
                    singleValue = seq[j] * seq[j + k]
                    sumValue = sumValue + singleValue
                ACF_Encode[i][k] = round(sumValue / (len(seq) - k), 2)
        ACF_Encode = ACF_Encode.flatten().tolist()
        return ACF_Encode

    # wt.write(time.strftime( ISOTIMEFORMAT, time.localtime( time.time() ) )+':acf11'+'\n')
    all_['doc2num'] = all_[0].apply(lambda ss: doc2num(ss))  # 将存在all_[0]中的序列以ss的名字导入doc2num，每次取一条序列
    # wt.write(time.strftime( ISOTIMEFORMAT, time.localtime( time.time() ) )+':acf12'+'\n')
    all_['doc2num1'] = all_[0].apply(lambda ss: doc2num1(ss))  # 将存在all_[0]中的序列以ss的名字导入doc2num1，每次取一条序列
    # wt.write(time.strftime( ISOTIMEFORMAT, time.localtime( time.time() ) )+':acf13'+'\n')
    # for i in list(all_['doc2num']):
    #     print(len(i))
    xy = np.array(list(all_['doc2num']), dtype=np.float64)
    x2 = xy.tolist()
    x = np.array(list(all_['doc2num1']), dtype=np.float64)
    x3 = x.tolist()

    # acl,aal=acf(list0[0])
    acl, aal = x2, x3
    # aal = x3
    # acn=acl
    # if  spes==9:aan=[a[100:-100] for a in aal]
    # elif spes==0 or s==8:aan=[a[200:-200] for a in aal]
    # else:aan=aal
    # acsl=ls(acl,'ACF')
    # aasl=ls(aal,'AAindex')
    return acl, aal  # acf,AAindex
    # return x3

# %%
def be1(list10, d):
    # import pandas as pd

    all_ = DataFrame(list10)
    abc = Series(range(0, 21),
                 index=['K', 'L', 'A', 'E', 'V', 'G', 'S', 'D', 'I', 'T', 'R', '*', 'P', 'Q', 'N', 'F', 'Y', 'M', 'H',
                        'C', 'W'])
    if d == 0: abc = Series(range(0, 22),
                            index=['K', 'L', 'A', 'E', 'V', 'G', 'S', 'D', 'I', 'T', 'R', '*', 'P', 'Q', 'N', 'F', 'Y',
                                   'M', 'H', 'C', 'W', 'U'])
    abc[:] = range(len(abc))
    word_set = set(abc.index)

    def doc2num(s):
        s = s.replace('X', '*')
        s = s.replace('B', '*')
        s = [i for i in s if i in word_set]
        return list(abc[s])

    all_['doc2num'] = all_[0].apply(lambda s: doc2num(s))
    for i, lew in enumerate(all_['doc2num']):
        if len(lew) != 21:
            print(all_[0][i])
    x = np.array(list(all_['doc2num']), dtype=np.int64)
    #gen_matrix = lambda z: (np_utils.to_categorical(z, len(abc)).flatten())
    gen_matrix = lambda z: (to_categorical(z, len(abc)).flatten())

    def data_generator(data, batch_size):
        batches = [range(batch_size * i, min(len(data), batch_size * (i + 1))) for i in
                   range(int(len(data) / batch_size + 1))]
        while True:
            for i in batches:
                xx = np.array(list(map(gen_matrix, data[i])))
            return (xx)

    x = data_generator(x[:], len(x) + 1)
    bin = x.tolist()
    return bin

# %%
def readweight(weight_file):
    weight = None
    with open(weight_file, 'r') as f:
        for i, line in enumerate(f):
            if i == 2 - 1:
                weight = np.array([float(x) for x in line.rstrip().split('\t')])
    return weight

# %%
# list:[k-mer]
def gps(list):
    global gpn
    for i, ii in enumerate(list):
        ii = ii.replace('U', '*')
        list[i] = ii

    # from keras.models import load_model

    def generateMMData(querylist, plist, pls_weight, mm_weight, loo=True, positive=False):
        gp = GpsPredictor(plist, pls_weight, mm_weight)

        d = []

        for query_peptide in querylist:
            d.append(gp.generateMMdata(query_peptide, loo).tolist())
        return d

    mm_weight = readweight('./results/BLOSUM62R.txt')  # 1th is intercept

    ll = len(list[0])
    #print(ll)
    #gpn = generateMMData(list, list, np.repeat(1, ll), mm_weight, loo=False, positive=False)
    #plist = readPeptide('./Protein/0.peptide',int(ll/2))
    plist = readPeptide('E:/NingLab/object/khib/results/pos_Khib.txt',30)
    #print(plist)
    gpn = generateMMData(list, plist,np.repeat(1, ll), mm_weight, loo=False, positive=False)# for p in nlist]
    return gpn

# %%
def readPeptide(pepfile, lr):
    data = []
    lr = 30 - lr
    print(lr)
    with open(pepfile, 'r') as f:
        for line in f:
            #print(line.rstrip().split('\t')[1])
            if lr == 0:
                data.append(line.rstrip().split('\t')[1])
            else:
                data.append(line.rstrip().split('\t')[1][lr:-lr])
    return data

# %%
class GpsPredictor(object):
    def __init__(self, plist, pls_weight, mm_weight):
        '''
        initial GPS predictor using positive training set, pls_weight vector and mm_weight vector
        :param plist: (list) positive peptides list
        :param pls_weight:  (list) pls_weight vector
        :param mm_weight:   (list) mm_weight vector
        '''
        self.alist = ['A', 'R', 'N', 'D', 'C', 'Q', 'E', 'G', 'H', 'I', 'L', 'K', 'M', 'F', 'P', 'S', 'T', 'W', 'Y',
                      'V', 'B', 'Z', 'X', '*']
        self.plist = plist
        self.pls_weight = np.array(pls_weight).flatten()
        self.mm_weight = np.array(mm_weight).flatten()

        self.__count_matrix = self._plist_index()
        self.__mm_matrix, self.__mm_intercept = self._mmweight2matrix()

    def predict(self, query_peptide, loo=False):
        '''
        return the gps score for the query peptide
        :param query_peptide: (str) query peptide
        :param loo: (bool) if true, count_matrix will minus 1 according to the amino acid in each position in query peptide
        :return: gps score
        '''
        count_clone = self.__count_matrix * len(self.plist)
        matrix = np.zeros_like(self.__count_matrix)
        for i, a in enumerate(query_peptide):
            if a not in self.alist: a = 'C'
            if loo: count_clone[i, self.alist.index(a)] -= 1
            matrix[i, :] = self.__mm_matrix[self.alist.index(a), :]
        rm_num = 1 if loo else 0
        pls_count_matrix = (count_clone.T * self.pls_weight).T / (len(self.plist) - rm_num)
        return np.sum(matrix * pls_count_matrix) + self.__mm_intercept

    def generatePLSdata(self, query_peptide, loo=False):
        '''
        generate the pls vector of query peptide
        :param query_peptide: (str) query peptide
        :param loo: (bool) if true, the count_matrix will minus 1 according to the amino acid in each position in query peptide
        :return: (np.ndarray) the vector of feature for each position
        '''
        count_clone = self.__count_matrix * len(self.plist)
        matrix = np.zeros_like(count_clone)
        for i, a in enumerate(query_peptide):
            if a not in self.alist: a = 'C'
            if loo:
                count_clone[i, self.alist.index(a)] -= 1

            matrix[i, :] = self.__mm_matrix[self.alist.index(a), :]
        rm_num = 1 if loo else 0
        count_clone = (count_clone.T * self.pls_weight).T
        return np.sum(matrix * count_clone / (len(self.plist) - rm_num), 1)

    def generateMMdata(self, query_peptide, loo=False):
        count_clone = self.__count_matrix * len(self.plist)

        indicator_matrix = np.zeros_like(count_clone)
        for i, a in enumerate(query_peptide):
            if a not in self.alist: a = 'C'
            if loo: count_clone[i, self.alist.index(a)] -= 1
            indicator_matrix[i, self.alist.index(a)] = 1

        rm_num = 1 if loo else 0

        count_clone /= (len(self.plist) - rm_num)

        pls_count_matrix = (count_clone.T * self.pls_weight).T

        m = np.dot(indicator_matrix.T, pls_count_matrix) * self.__mm_matrix

        m += m.T

        np.fill_diagonal(m, np.diag(m) / float(2))

        iu1 = np.triu_indices(m.shape[0])

        return m[iu1]

    def getcutoff(self, randompeplist, sp=[0.98, 0.95, 0.85]):
        '''
        return cutoffs using 10000 random peptides as negative
        :param randompeplist: (list) random generated peptides
        :param sp: (float list) sp to be used for cutoff setting
        :return: (float list) cutoffs, same lens with sp
        '''
        rand_scores = sorted([self.predict(p) for p in randompeplist])
        cutoffs = np.zeros(len(sp))
        for i, s in enumerate(sp):
            index = np.floor(len(rand_scores) * s).astype(int)
            cutoffs[i] = rand_scores[index]
        return cutoffs

    def _plist_index(self):
        '''
        return the amino acid frequency on each position, row: position, column: self.alist, 61 x 24
        :return: count matrix
        '''
        n, m = len(self.plist[0]), len(self.alist)
        count_matrix = np.zeros((n, m))
        for i in range(n):
            for p in self.plist:
                count_matrix[i][self.alist.index(p[i])] += 1
        return count_matrix / float(len(self.plist))

    def _mmweight2matrix(self):
        '''
        convert matrix weight vector to similarity matrix, 24 x 24, index order is self.alist
        :return:
        '''
        aalist = self.getaalist()
        mm_matrix = np.zeros((len(self.alist), len(self.alist)))
        for n, d in enumerate(aalist):
            value = self.mm_weight[n + 1]  # mm weight contain intercept
            i, j = self.alist.index(d[0]), self.alist.index(d[1])
            mm_matrix[i, j] = value
            mm_matrix[j, i] = value
        return mm_matrix, self.mm_weight[0]

    def getaalist(self):
        '''return aa-aa list
        AA: 0
        AR: 1
        '''
        aa = [self.alist[i] + self.alist[j] for i in range(len(self.alist)) for j in range(i, len(self.alist))]
        return aa

# %%
# 氨基酸对组成 0、1、2、3
def kmors(list10, km, m='l'):
    # global kmn
    pos = DataFrame(list10)
    all_ = pos
    aalist = []
    if m == 'd':
        ablist = ['A', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'K', 'L', 'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'V', 'W', 'Y']
    else:
        ablist = ['A', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'K', 'L', 'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'V', 'W', 'X',
                  'Y']
    for aa in ablist:
        for bb in ablist:
            aalist.append(aa + bb)

    def doc2num(s):
        ssss = []
        for k in range(km):
            alist = []
            for i, a in enumerate(s):
                if i + k + 1 < len(s):
                    alist.append(a + s[i + k + 1])
                else:
                    continue
            ss = [float(alist.count(i)) for i in aalist]
            ssss = ssss + ss[:]
        return list(ssss)

    all_['doc2num'] = all_[0].apply(lambda s: doc2num(s))
    x = np.array(list(all_['doc2num']), dtype=np.int64)
    x2 = x.tolist()
    return x2

# %%
# 氨基酸组成
def aac1(list10):
    pos = DataFrame(list10)
    all_ = pos
    aalist = ['A', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'K', 'L', 'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'V', 'W', 'Y']
    ll = len(list10[0])

    def doc2num(s):
        s = [float(s.count(i) / ll) for i in aalist]
        s = s[:]
        return list(s)

    all_['doc2num'] = all_[0].apply(lambda s: doc2num(s))

    x = np.array(list(all_['doc2num']), dtype=np.float64)
    x2 = x.tolist()
    return x2

# %%
def pssm1(list10, dic, protname):
    print('pssm1')
    global ppf
    ppf = {}
    # pp=open('./pssm/pssm.txt','r')
    # for l in pp:
    #     l=l.rstrip().split('\t')
    #     ppf[l[0]]=l[1]+'\t'+l[2]+'\t'+l[3]
    pnlist = list10
    # sp2 = ['all', 'Homo_sapiens', 'Mus_musculus', 'Saccharomyces_cerevisiae', 'Oryza_sativa', 'Rattus_norvegicus',
    #        'Escherichia_coli', 'Solanum_lycopersicum',
    #        'Bacillus_subtilis', 'Brachypodium_distachyon', 'Corynebacterium_glutamicum', 'Mycobacterium_tuberculosis',
    #        'Toxoplasma_gondii', 'Vibrio_parahaemolyticus']
    # sp2=['all']
    # for i in sp2:
    #     if i==sp2[spe]:continue
    #     if not os.path.exists('./pssm/'+i+'ps.txt'):continue
    #     pp = open('./pssm/'+i+'ps.txt', 'r')
    #     for l in pp:
    #         l = l.rstrip().split('\t')
    #         ppf[l[0]] = l[1] + '\t' + './pssm/'+l[2] + '\t' +'./pssm/'+ l[3]
    # for i in sp2:
    #     if i == sp2[spe]: continue
    #     if not os.path.exists('./pssm/aa' + i + '.txt'):continue
    #     pp = open('./pssm/aa' + i + '.txt', 'r')
    #     for l in pp:
    #         if not l.count('\t')==3:continue
    #         l = l.rstrip().split('\t')
    #         ppf[l[0]] = l[1] + '\t' + l[2] + '\t' + l[3]
    with open(dic + '/Protein.txt', 'w') as fout:
        for it, iter in enumerate(pnlist):
            fout.write('>sp|' + str(protname[it]) + '|' + '\n')
            fout.write(iter + "\n")
    ProSeq = outdic + "Protein.txt"
    OutDir = outdic + 'ZFilepathresult'
    PSSMDir = outdic + 'ZFilepathPSSM'
    DBname = outdic + 'ZDB/DB'
    GetPSSM(ProSeq, OutDir, PSSMDir, DBname)
    # time.strftime( ISOTIMEFORMAT, time.localtime( time.time() ) )+':pssm1'+'\n')

# %%
def command_pssm(input_file, output_file, pssm_file, DBname):
    import subprocess
    try:
        cmd1 = r'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query ' + input_file + ' -db ' + DBname + ' -num_iterations 3 -num_threads 12 -out ' + output_file + ' -out_ascii_pssm ' + pssm_file
        # wt.write(time.strftime( ISOTIMEFORMAT, time.localtime( time.time() ) )+':pssm11'+input_file+'\n')
        subprocess.run(cmd1, shell=True, check=True)
    except subprocess.CalledProcessError as e:
        print("Error:", e)

# %%
def GetPSSM(ProSeq, OutDir, PSSMDir, DBname):
    from Bio import SeqIO
    records = list(SeqIO.parse(ProSeq, "fasta"))

    global aa1
    aa1 = {}
    # aa=open('../../pssm/aa.txt','a')
    for i, item in enumerate(records):
        if not os.path.exists(r'ZID/'):
            os.makedirs(r'ZID/')
        # print(records[i].seq,records[i].seq in ppf,ppf.__len__())
        if records[i].seq in ppf:
            seq1 = records[i].seq
            # print(seq1)
            if ppf[seq1].split('\t')[1] == 'nan': continue
            input1 = ppf[seq1].split('\t')[1]
            input2 = ppf[seq1].split('\t')[2]
            if (not os.path.exists(input1)) or (not os.path.exists(input2)): continue
            out1 = PSSMDir + r'/' + records[i].id.split('|')[1] + '.pssm'
            out2 = PSSMDir[:-14] + r'/asa_result2/' + records[i].id.split('|')[1] + '.txt'
            import shutil
            shutil.copy(input1, out1)
            shutil.copy(input2, out2)
            # print(seq1,records[i].seq)
            aa1[str(seq1)] = input1
        else:
            input_file = outdic + r'ZID/'  + records[i].id.split('|')[1] + '.fa'
            SeqIO.write(records[i], input_file, 'fasta')

            output_file = OutDir + r'/' + records[i].id.split('|')[1] + '.out'
            pssm_file = PSSMDir + r'/' + records[i].id.split('|')[1] + '.pssm'

            if not os.path.exists(pssm_file):
                command_pssm(input_file, output_file, pssm_file, DBname)
            aa1[str(records[i].seq)] = pssm_file

# %%
def ss1(list10, dic):
    global sn, asal, ssl, asan, ssn, asasl, sssl
    OldPSMMdir = dic + '/ZFilepathPSSM'
    origin_outfile = dic + '/asa_result'
    detial_pssm = OldPSMMdir + '/'
    outfile = origin_outfile + '/'
    if not os.path.exists(outfile):
        os.makedirs(outfile)
    print(outfile)
    next_listfile = os.listdir(detial_pssm)
    # next_listfile.sort(key=lambda x: int(x[0:-5]))
    for i, pssm_file in enumerate(next_listfile):
        if os.path.exists(outfile + pssm_file.split('.')[0] + '.txt'): continue
        nndir = r'E:/NingLab/object/khib/SS/'
        dict1_nn = load_NN(nndir + 'pp1.npz')
        dict2_nn = load_NN(nndir + 'pp2.npz')
        dict3_nn = load_NN(nndir + 'pp3.npz')
        list_nn = (dict1_nn, dict2_nn, dict3_nn)
        print(pssm_file)
        main(list_nn, detial_pssm + '/' + pssm_file, outfile, r'txt')
    sn, asal, ssl, btal, namesout = ss(dic)
    # print(asal)
    # asan, ssn = asal, ssl
    # asasl =ls(asal, 'ASA')
    # sssl =ls(ssl, 'SS')
    return asal, ssl, btal, namesout  # ASA, SS, BTA

# %%
def main(list_params, pssm_file, outfile, out_suffix):
    basenm = os.path.basename(pssm_file)
    if basenm.endswith('.pssm'):
        basenm = basenm[:-5]
    elif basenm.endswith('.mat'):
        basenm = basenm[:-4]

    outfile0 = '%s%s.%s' % (outfile, basenm, out_suffix)  #

    aa, pssm = read_pssm(pssm_file)
    pred1(list_params, aa, pssm, outfile0)
def load_NN(nn_filename):
    return np.load(nn_filename, mmap_mode=None, allow_pickle=True, fix_imports=True,
                   encoding="latin1")  # load in the NN mat file.

# %%
def read_pssm(pssm_file):
    # this function reads the pssm file given as input, and returns a LEN x 20 matrix of pssm values.
    # index of 'ACDE..' in 'ARNDCQEGHILKMFPSTWYV'(blast order)
    idx_res = (0, 4, 3, 6, 13, 7, 8, 9, 11, 10, 12, 2, 14, 5, 1, 15, 16, 19, 17, 18)
    # open the two files, read in their data and then close them
    # declare the empty dictionary with each of the entries
    aa = []
    pssm = []
    # iterate over the pssm file and get the needed information out
    with open(pssm_file) as inputpssm:
        count = 0
        for line in inputpssm:

            count += 1
            if count <= 3:
                continue
            if line.count('\n') == len(line):
                break
            temp = line.strip().split()[2:22]
            aa_temp = line.strip().split()[1]
            aa.append(aa_temp)
            pssm_temp = [-float(i) for i in temp]
            pssm.append([pssm_temp[k] for k in idx_res])
    return aa, pssm

# %%
def pred1(list_params, aa, pssm, outfile0):
    list_nn = list_params
    phys = get_phys7(aa)
    input_feature = window_data(pssm, phys)
    ## DO FIRST PREDICTIONS
    for it1 in (1, 2, 3):
        ofile = outfile0
        if it1 < 3: ofile = 'NULL'
        dict_nn = list_nn[it1 - 1]
        res1 = run_iter(dict_nn, input_feature, aa, ofile)
        if it1 == 3: break
        ## feature after 1st iteration
        SS_1, pred_ss_1, pred_asa_1, theta, tau, phi, psi = res1
        tt_input = np.sin(np.concatenate((np.radians(theta), np.radians(tau)), axis=1)) / 2 + 0.5
        tt_input = np.concatenate(
            (tt_input, np.cos(np.concatenate((np.radians(theta), np.radians(tau)), axis=1)) / 2 + 0.5), axis=1)
        pp_input = np.sin(np.concatenate((np.radians(phi), np.radians(psi)), axis=1)) / 2 + 0.5
        pp_input = np.concatenate(
            (pp_input, np.cos(np.concatenate((np.radians(phi), np.radians(psi)), axis=1)) / 2 + 0.5), axis=1)
        ttpp_input = np.concatenate((tt_input, pp_input), axis=1)
        input_feature = window_data(pssm, phys, pred_ss_1, pred_asa_1, ttpp_input)

# %%
def get_phys7(aa):
    # this function takes a path to a pssm file and finds the pssm + phys 7 input
    # to the NN in the required order - with the required window size (8).
    # define the dictionary with the phys properties for each AA
    phys_dic = {'A': [-0.350, -0.680, -0.677, -0.171, -0.170, 0.900, -0.476],
                'C': [-0.140, -0.329, -0.359, 0.508, -0.114, -0.652, 0.476],
                'D': [-0.213, -0.417, -0.281, -0.767, -0.900, -0.155, -0.635],
                'E': [-0.230, -0.241, -0.058, -0.696, -0.868, 0.900, -0.582],
                'F': [0.363, 0.373, 0.412, 0.646, -0.272, 0.155, 0.318],
                'G': [-0.900, -0.900, -0.900, -0.342, -0.179, -0.900, -0.900],
                'H': [0.384, 0.110, 0.138, -0.271, 0.195, -0.031, -0.106],
                'I': [0.900, -0.066, -0.009, 0.652, -0.186, 0.155, 0.688],
                'K': [-0.088, 0.066, 0.163, -0.889, 0.727, 0.279, -0.265],
                'L': [0.213, -0.066, -0.009, 0.596, -0.186, 0.714, -0.053],
                'M': [0.110, 0.066, 0.087, 0.337, -0.262, 0.652, -0.001],
                'N': [-0.213, -0.329, -0.243, -0.674, -0.075, -0.403, -0.529],
                'P': [0.247, -0.900, -0.294, 0.055, -0.010, -0.900, 0.106],
                'Q': [-0.230, -0.110, -0.020, -0.464, -0.276, 0.528, -0.371],
                'R': [0.105, 0.373, 0.466, -0.900, 0.900, 0.528, -0.371],
                'S': [-0.337, -0.637, -0.544, -0.364, -0.265, -0.466, -0.212],
                'T': [0.402, -0.417, -0.321, -0.199, -0.288, -0.403, 0.212],
                'V': [0.677, -0.285, -0.232, 0.331, -0.191, -0.031, 0.900],
                'W': [0.479, 0.900, 0.900, 0.900, -0.209, 0.279, 0.529],
                'Y': [0.363, 0.417, 0.541, 0.188, -0.274, -0.155, 0.476]}
    # set the phys7 data.
    phys = [phys_dic.get(i, phys_dic['A']) for i in aa]
    return phys

# %%
def window(feat, winsize=8):
    # apply the windowing to the input feature
    feat = np.array(feat)
    output = np.concatenate([np.vstack([feat[0]] * winsize), feat])
    output = np.concatenate([output, np.vstack([feat[-1]] * winsize)])
    output = [np.ndarray.flatten(output[i:i + 2 * winsize + 1]).T for i in range(0, feat.shape[0])]
    return output

def window_data(*feature_types):
    n = len(feature_types[0])
    features = np.empty([n, 0])
    for feature_type in feature_types:
        test = np.array(window(feature_type))
        features = np.concatenate((features, test), axis=1)
    return features

# %%
def run_iter(dict_nn, input_feature0, aa, ofile):
    SS_order = ('C' 'E' 'H')
    list1 = ('SS', 'ASA', 'TTPP')
    list_res1 = []
    for x in list1:
        nn = dict_nn[x]
        norm_max = nn['high'][0][0][0]
        norm_min = nn['low'][0][0][0]
        input_feature1 = (input_feature0 - np.tile(norm_min, (input_feature0.shape[0], 1))) / np.tile(
            (norm_max - norm_min), (input_feature0.shape[0], 1))
        r1 = nn_feedforward(nn, input_feature1)
        list_res1.append(r1)
    pred_ss_1, pred_asa_1, pred_ttpp_1 = list_res1
    SS_1 = [SS_order[i.tolist()[0][0]] for i in np.argmax(pred_ss_1, 1)]
    pred_ttpp_1_denorm = (pred_ttpp_1 - 0.5) * 2
    theta = np.degrees(np.arctan2(pred_ttpp_1_denorm[:, 0], pred_ttpp_1_denorm[:, 2]))
    tau = np.degrees(np.arctan2(pred_ttpp_1_denorm[:, 1], pred_ttpp_1_denorm[:, 3]))
    phi = np.degrees(np.arctan2(pred_ttpp_1_denorm[:, 4], pred_ttpp_1_denorm[:, 6]))
    psi = np.degrees(np.arctan2(pred_ttpp_1_denorm[:, 5], pred_ttpp_1_denorm[:, 7]))
    if ofile == 'NULL':
        return SS_1, pred_ss_1, pred_asa_1, theta, tau, phi, psi
    fp = open(ofile, 'w')
    fp.write('#\tAA\tSS\tASA\tPhi\tPsi\tTheta(i-1=>i+1)\tTau(i-2=>i+1)\tP(C)\tP(E)\tP(H)')
    fp.write('\n')
    for ind, x in enumerate(aa):
        asa = pred_asa_1[ind] * dict_ASA0.get(x, dict_ASA0['A'])

        fp.write(('%i\t%c\t%c\t%5.1f' + '\t%6.1f' * 4 + '\t%.3f' * 3) % (
            ind + 1, x, SS_1[ind], asa, phi[ind], psi[ind], theta[ind], tau[ind], pred_ss_1[ind, 0], pred_ss_1[ind, 1],
            pred_ss_1[ind, 2]))
        fp.write('\n')
    fp.close()
    return SS_1, pred_ss_1, pred_asa_1, theta, tau, phi, psi

# %%
def sigmoid(input):
    # apply the sigmoid function
    output = 1 / (1 + np.exp(-input))
    return (output)

def nn_feedforward(nn, input):
    input = np.matrix(input)
    # find the number of layers in the NN so that we know how much to iterate over
    num_layers = nn['n'][0][0][0][0]
    # num_input is the number of input AAs, not the dimentionality of the features
    num_input = input.shape[0]
    x = input
    # for each layer up to the final
    for i in range(1, num_layers - 1):
        # get the bais and weights out of the nn
        W = nn['W'][0][0][0][i - 1].T
        temp_size = x.shape[0]
        b = np.ones((temp_size, 1))
        x = np.concatenate((b, x), axis=1)
        # find the output of this layer (the input to the next)
        xw = np.dot(x, W)
        x = sigmoid(xw)
    # for the final layer.
    # note that this layer is done serpately, this is so that if the output nonlinearity
    # is not sigmoid, it can be calculated seperately.
    W = nn['W'][0][0][0][-1].T
    b = np.ones((x.shape[0], 1))
    x = np.concatenate((b, x), axis=1)
    output = np.dot(x, W)  # x*W
    pred = sigmoid(output)
    return pred

dict_ASA0 = dict(zip("ACDEFGHIKLMNPQRSTVWY",
                     (115, 135, 150, 190, 210, 75, 195, 175, 200, 170,
                      185, 160, 145, 180, 225, 115, 140, 155, 255, 230)))

# %%
def ss(dic):
    OldPSMMdir = dic + '/asa_result'  # 输出
    FinPSSM, FinPSSM1, FinPSSM2, num, namesout = psStandardpPSSM(OldPSMMdir)
    xy = np.array(list(FinPSSM), dtype=np.float64)
    x2 = xy.tolist()
    xy1 = np.array(list(FinPSSM1), dtype=np.float64)
    x3 = xy1.tolist()
    xy2 = np.array(list(FinPSSM2), dtype=np.float64)
    x4 = xy2.tolist()
    return num, x2, x3, x4, namesout

# %%
def psStandardpPSSM(OldPSMMdir):
    listfile = os.listdir(OldPSMMdir)
    if listfile.__len__() == 0:
        import shutil
        shutil.copy('../1.txt', OldPSMMdir)
    listfile = os.listdir(OldPSMMdir)
    FinPSSM, FinPSSM0, FinPSSM1, num1 = [], [], [], []
    for i, eachfile in enumerate(listfile):
        # print(eachfile)
        # num1.append(int(eachfile.split('.')[0]))
        num1.append(eachfile.split('.')[0])
    num = sorted(num1)
    namesout = []
    # global namesout
    for i, nn in enumerate(num):
        eachfile = str(nn) + '.txt'
        # print(eachfile)
        with open(OldPSMMdir + '/' + eachfile, 'r') as inputpssm:
            count = 0
            Dirdata, Dirdata0, Dirdata1, Dirdata2, Dirdata3 = [], [], [], [], []
            Dirdata4, Dirdata5, Dirdata6, Dirdata7, Dirdata8 = [], [], [], [], []
            for line in inputpssm:
                count += 1
                if count <= 1:
                    continue
                if len(line) < 2:
                    break
                # print(line)
                temp = float(line.strip().split('\t')[3])
                Dirdata.append(temp)
                temp0 = float(line.strip().split('\t')[8])
                Dirdata0.append(temp0)
                temp1 = float(line.strip().split('\t')[9])
                Dirdata1.append(temp1)
                temp2 = float(line.strip().split('\t')[10])
                Dirdata2.append(temp2)
                temp3 = float(line.strip().split('\t')[4])
                Dirdata4.append(temp3)
                temp4 = float(line.strip().split('\t')[5])
                Dirdata5.append(temp4)
                temp5 = float(line.strip().split('\t')[6])
                Dirdata6.append(temp5)
                temp6 = float(line.strip().split('\t')[7])
                Dirdata7.append(temp6)

            Dirdata3 = Dirdata0 + Dirdata1 + Dirdata2
            Dirdata8 = Dirdata4 + Dirdata5 + Dirdata6 + Dirdata7
            # if Dirdata == [] or len(Dirdata) != 61:
            # print(len(Dirdata))
            # continue
            FinPSSM.append(Dirdata)
            FinPSSM0.append(Dirdata3)
            FinPSSM1.append(Dirdata8)
            namesout.append(nn)
            # print(len(Dirdata),len(Dirdata3),len(Dirdata8))#61 183 244 (21 63 84)
    # print(FinPSSM[0],FinPSSM[1],FinPSSM[2],FinPSSM[3])
    # print(FinPSSM0[0], FinPSSM0[1], FinPSSM0[2], FinPSSM0[3])
    # print(FinPSSM1[0], FinPSSM1[1], FinPSSM1[2], FinPSSM1[3])
    # FinPSSM=np.array(FinPSSM).reshape(len(num),len(Dirdata))
    # FinPSSM0 = np.array(FinPSSM0).reshape(len(num), len(Dirdata3))
    # FinPSSM1 = np.array(FinPSSM1).reshape(len(num), len(Dirdata8))
    # print(np.array(FinPSSM).shape,np.array(FinPSSM0).shape,np.array(FinPSSM1).shape)

    return FinPSSM, FinPSSM0, FinPSSM1, num, namesout
    # FinPSSM:asa FinPSSM0:二级结构 FinPSSM1：四个角度
    # secondary structure type, ASA, φ, ψ, θ, τ, and probabilities as coil (C), sheet (E), and helix (H)

# %%
def storage10features(storehouse, namelist, acf, aaindex, obc, gps, cksaap, pseaac, asa, ss, bta,
                      pssmframe, label):  # all of them are lists
    if label == 0:
        storehouse = storehouse + '10features_for_negative_data/'
    elif label == 1:
        storehouse = storehouse + '10features/'
    else:
        storehouse = storehouse + '10features_for_experiment1/'
    if not os.path.exists(storehouse):
        os.makedirs(storehouse)
    with open(storehouse + 'peptides.txt', mode='w') as f1:
        for name in namelist:
            if name in pepdic.keys():
                f1.write(name + '\n')

    def storefeature(name, featurename, feature):
        if not os.path.exists(storehouse + featurename):
            os.makedirs(storehouse + featurename)
        with open(storehouse + featurename + '/' + name + '.' + str.lower(featurename), mode='w') as file:
            for fea in feature:
                file.write(str(fea) + '\t')
            file.write('\n')

    for iter, item in enumerate(namelist):  # iter[index] item[pepname] namelist 24295
        if item in pepdic.keys(): # 用PSSM的24025
            #print(item)
            #print(iter)
            storefeature(item, 'ACF', ACF[iter]) # 24295
            storefeature(item, 'AAINDEX', AAindex[iter]) 
            storefeature(item, 'OBC', binary[iter])
            storefeature(item, 'GPS', gpn[iter])
            storefeature(item, 'CKSAAP', CKSAAPs[iter])
            storefeature(item, 'PSEAAC', PseAAC[iter])
            #storefeature(item, 'ASA', ASA[iter]) # 24038
            #storefeature(item, 'SS', SS[iter]) # 24038
            #storefeature(item, 'BTA', BTA[iter]) # 24038
            #storefeature(item, 'PSSM', pssmframe[iter]) # 24038
    
    namelist1=list(pepdic.keys()) #24038
    for iter, item in enumerate(namelist1):  
        if item in pepdic.keys(): 
            print(item)
            print(iter)
            storefeature(item, 'ASA', ASA[iter]) # 24038
            storefeature(item, 'SS', SS[iter]) # 24038
            storefeature(item, 'BTA', BTA[iter]) # 24038
            storefeature(item, 'PSSM', pssmframe[iter]) # 24038

# %%
len(pepdic.keys())
# Out:
# 24295

# %%
#pepdic:{ID:peptide}
outdic = 'E:/NingLab/object/khib/results/'
txt = open('E:/NingLab/object/khib/results/pos_Khib.txt', mode='r')
txt = txt.readlines()
pepdic = {}
for line in txt:
    line = line.rstrip().split('\t')
    if len(line[1]) != 21:
        continue
    pepdic[line[0]] = line[1]
namelist=list(pepdic.keys())
peplist=list(pepdic.values())

# %%
ACF, AAindex=acf(peplist)

d=1
binary=be1(peplist,d)

# %%
gpn=gps(peplist)

km=1
CKSAAPs=kmors(peplist,km,m='l')

# %%
PseAAC=aac1(peplist)

# %%
pssm1(peplist,outdic ,namelist)
# Out:
# pssm1
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/P60174_285.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/P60174_285.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/P60174_285.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/A0A0G2JSP3_720.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/A0A0G2JSP3_720.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/A0A0G2JSP3_720.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/A0A0G2JVM0_551.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/A0A0G2JVM0_551.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/A0A0G2JVM0_551.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/A0A0G2JVM0_547.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/A0A0G2JVM0_547.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/A0A0G2JVM0_547.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/A0A0G2JVW5_3997.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/A0A0G2JVW5_3997.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/A0A0G2JVW5_3997.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/A0A0G2K0H9_452.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/A0A0G2K0H9_452.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/A0A0G2K0H9_452.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/A0A0G2K459_293.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/A0A0G2K459_293.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/A0A0G2K459_293.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/A0A0G2K8P2_827.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/A0A0G2K8P2_827.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/A0A0G2K8P2_827.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/A0A0G2KAM4_463.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/A0A0G2KAM4_463.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/A0A0G2KAM4_463.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/A0A0G2KAM4_470.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/A0A0G2KAM4_470.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/A0A0G2KAM4_470.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/A0A0H2UHM5_499.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/A0A0H2UHM5_499.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/A0A0H2UHM5_499.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/A0A0H2UHM5_501.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/A0A0H2UHM5_501.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/A0A0H2UHM5_501.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/A0A0H2UHP1_515.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/A0A0H2UHP1_515.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/A0A0H2UHP1_515.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/A0A0U1RRQ7_329.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/A0A0U1RRQ7_329.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/A0A0U1RRQ7_329.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/A0A140UHX6_2220.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/A0A140UHX6_2220.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/A0A140UHX6_2220.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/A0A1B0GWR1_329.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/A0A1B0GWR1_329.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/A0A1B0GWR1_329.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3Z8C2_374.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3Z8C2_374.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3Z8C2_374.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_2482.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_2482.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_2482.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_2477.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_2477.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_2477.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_1948.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_1948.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_1948.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_690.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_690.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_690.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_688.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_688.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_688.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_2090.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_2090.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_2090.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_1789.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_1789.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_1789.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_1546.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_1546.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_1546.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_360.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_360.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_360.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_2105.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_2105.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_2105.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_2116.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_2116.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_2116.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_258.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_258.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_258.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_265.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_265.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_265.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_287.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_287.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_287.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_1192.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_1192.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_1192.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_2086.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_2086.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_2086.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_2430.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_2430.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_2430.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_864.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_864.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_864.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_337.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_337.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_337.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_1322.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_1322.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_1322.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_1088.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_1088.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_1088.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_1316.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_1316.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_1316.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_2164.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_2164.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_2164.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_2531.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_2531.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_2531.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_857.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_857.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_857.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_1070.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_1070.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_1070.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_1961.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_1961.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_1961.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_2025.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_2025.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_2025.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_1042.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_1042.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_1042.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_348.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_348.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_348.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_2493.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_2493.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_2493.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_1782.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_1782.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_1782.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_2134.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_2134.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_2134.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_913.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_913.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_913.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_1934.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_1934.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_1934.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_744.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_744.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_744.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZA84_538.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZA84_538.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZA84_538.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZCZ9_100.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZCZ9_100.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZCZ9_100.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZCZ9_112.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZCZ9_112.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZCZ9_112.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZCZ9_90.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZCZ9_90.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZCZ9_90.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZCZ9_97.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZCZ9_97.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZCZ9_97.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D3ZD02_208.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D3ZD02_208.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D3ZD02_208.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/D4A6E5_687.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/D4A6E5_687.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/D4A6E5_687.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/F1LN42_1908.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/F1LN42_1908.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/F1LN42_1908.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/Q5BJU2_574.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/Q5BJU2_574.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/Q5BJU2_574.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/Q5BJU2_879.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/Q5BJU2_879.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/Q5BJU2_879.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/Q5BJU2_711.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/Q5BJU2_711.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/Q5BJU2_711.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/F1LSM5_1086.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/F1LSM5_1086.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/F1LSM5_1086.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/F1LVF9_162.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/F1LVF9_162.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/F1LVF9_162.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/F1M2K6_572.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/F1M2K6_572.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/F1M2K6_572.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/F1M983_756.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/F1M983_756.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/F1M983_756.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/F1M983_881.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/F1M983_881.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/F1M983_881.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/F1M983_874.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/F1M983_874.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/F1M983_874.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/F1M983_853.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/F1M983_853.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/F1M983_853.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/F1M983_925.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/F1M983_925.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/F1M983_925.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/F2Z3T9_458.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/F2Z3T9_458.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/F2Z3T9_458.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/G3V827_439.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/G3V827_439.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/G3V827_439.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/G3V827_437.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/G3V827_437.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/G3V827_437.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/G3V827_425.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/G3V827_425.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/G3V827_425.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/G3V8C3_439.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/G3V8C3_439.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/G3V8C3_439.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/G3V8C3_445.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/G3V8C3_445.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/G3V8C3_445.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/G3V8L9_256.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/G3V8L9_256.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/G3V8L9_256.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/G3V8L9_301.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/G3V8L9_301.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/G3V8L9_301.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/G3V8L9_278.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/G3V8L9_278.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/G3V8L9_278.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/G3V8L9_314.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/G3V8L9_314.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/G3V8L9_314.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/G3V8L9_319.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/G3V8L9_319.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/G3V8L9_319.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/G3V8L9_328.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/G3V8L9_328.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/G3V8L9_328.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/G3V8L9_262.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/G3V8L9_262.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/G3V8L9_262.pssm' returned non-zero exit status 3.
# Error: Command 'D:/NCBI/blast-2.15.0+/bin/psiblast.exe -query E:/NingLab/object/khib/ZID/G3V8L9_267.fa -db E:/NingLab/object/khib/results/ZDB/DB -num_iterations 3 -num_threads 12 -out E:/NingLab/object/khib/results/ZFilepathresult/G3V8L9_267.out -out_ascii_pssm E:/NingLab/object/khib/results/ZFilepathPSSM/G3V8L9_267.pssm' returned non-zero exit status 3.

# %%
ASA, SS, BTA, namesout = ss1(peplist, outdic)
bas_feat={}
del_list = []
for basname in pepdic.keys():
    if not os.path.exists(outdic+"/ZFilepathPSSM/%s.pssm"%(basname)):
        del_list.append(basname)
for del_name in del_list:
    del pepdic[del_name]
for basname in pepdic.keys():
    pssm=open(outdic+"/ZFilepathPSSM/%s.pssm"%(basname),'r').readlines()[3:24]
    # print(basname)
    bas_feat[basname] = []
    for line in pssm:
        if line.startswith(' '):
            dat=[i for i in line.strip().split(' ')[2:] if i!='']
            dat=dat[:20]
            bas_feat[basname]+=dat
# Out:
# E:/NingLab/object/khib/results//asa_result/

# %%
pssmframe=pd.DataFrame.from_dict(bas_feat, orient='index')
pssmframe.columns=['pssm~'+str(i) for i in pssmframe.columns]
pssmframe=np.array(pssmframe.values).astype(int)

# %%
print(f"Length of namelist: {len(namelist)}")
print(f"Length of ACF: {len(ACF)}")
print(f"Length of AAindex: {len(AAindex)}")
print(f"Length of binary: {len(binary)}")
print(f"Length of gpn: {len(gpn)}")
print(f"Length of CKSAAPs: {len(CKSAAPs)}")
print(f"Length of PseAAC: {len(PseAAC)}")
print(f"Length of ASA: {len(ASA)}")
print(f"Length of SS: {len(SS)}")
print(f"Length of BTA: {len(BTA)}")
print(f"Length of pssmframe: {len(pssmframe)}")
# Out:
# Length of namelist: 24295
# Length of ACF: 24295
# Length of AAindex: 24295
# Length of binary: 24295
# Length of gpn: 24295
# Length of CKSAAPs: 24295
# Length of PseAAC: 24295
# Length of ASA: 24038
# Length of SS: 24038
# Length of BTA: 24038
# Length of pssmframe: 24038

# %%
storage10features('E:/NingLab/object/khib/results/', namelist, ACF, AAindex, binary, gpn, CKSAAPs, PseAAC, ASA, SS, BTA, pssmframe,
                  1)

# %%
def storagegpsfeatures(storehouse, namelist, gps, label):  
    if label == 0:
        storehouse = storehouse + '10features_for_negative_data/'
    elif label == 1:
        storehouse = storehouse + '10features/'
    else:
        storehouse = storehouse + '10features_for_experiment1/'
    if not os.path.exists(storehouse):
        os.makedirs(storehouse)
    with open(storehouse + 'peptides.txt', mode='w') as f1:
        for name in namelist:
            if name in pepdic.keys():
                f1.write(name + '\n')

    def storefeature(name, featurename, feature):
        if not os.path.exists(storehouse + featurename):
            os.makedirs(storehouse + featurename)
        with open(storehouse + featurename + '/' + name + '.' + str.lower(featurename), mode='w') as file:
            for fea in feature:
                file.write(str(fea) + '\t')
            file.write('\n')

    for iter, item in enumerate(namelist):  # iter[index] item[pepname] namelist 24295
        if item in pepdic.keys(): # 用PSSM的24038
            #print(item)
            #print(iter)
            storefeature(item, 'GPS', gpn[iter]) # 24295 24038

# %%
#storagegpsfeatures('E:/NingLab/object/khib/results/', namelist, gpn, 1)

# %%
#pepdic:{ID:peptide}
#negative
outdic = 'E:/NingLab/object/khib/results/10negative/'
txt = open('E:/NingLab/object/khib/results/neg_Khib.txt', mode='r')
txt = txt.readlines()
pepdic = {}
for line in txt:
    line = line.rstrip().split('\t')
    if len(line[1]) != 21:
        continue
    pepdic[line[0]] = line[1]
namelist=list(pepdic.keys())
peplist=list(pepdic.values())

# %%
ACF, AAindex=acf(peplist)

d=1
binary=be1(peplist,d)

# %%
gpn=gps(peplist)
km=1
CKSAAPs=kmors(peplist,km,m='l')
# Out:
# 0

# %%
PseAAC=aac1(peplist)

# %%
pssm1(peplist,outdic ,namelist)
# Out:
# pssm1

# %%
ASA, SS, BTA, namesout = ss1(peplist, outdic)
bas_feat={}
del_list = []
for basname in pepdic.keys():
    if not os.path.exists(outdic+"/ZFilepathPSSM/%s.pssm"%(basname)):
        del_list.append(basname)
for del_name in del_list:
    del pepdic[del_name]
for basname in pepdic.keys():
    pssm=open(outdic+"/ZFilepathPSSM/%s.pssm"%(basname),'r').readlines()[3:24]
    # print(basname)
    bas_feat[basname] = []
    for line in pssm:
        if line.startswith(' '):
            dat=[i for i in line.strip().split(' ')[2:] if i!='']
            dat=dat[:20]
            bas_feat[basname]+=dat
# Out:
# E:/NingLab/object/khib/results/10negative//asa_result/

# %%
pssmframe=pd.DataFrame.from_dict(bas_feat, orient='index')
pssmframe.columns=['pssm~'+str(i) for i in pssmframe.columns]
pssmframe=np.array(pssmframe.values).astype(int)

# %%
print(f"Length of namelist: {len(namelist)}")
print(f"Length of ACF: {len(ACF)}")
print(f"Length of AAindex: {len(AAindex)}")
print(f"Length of binary: {len(binary)}")
print(f"Length of gpn: {len(gpn)}")
print(f"Length of CKSAAPs: {len(CKSAAPs)}")
print(f"Length of PseAAC: {len(PseAAC)}")
print(f"Length of ASA: {len(ASA)}")
print(f"Length of SS: {len(SS)}")
print(f"Length of BTA: {len(BTA)}")
print(f"Length of pssmframe: {len(pssmframe)}")
# Out:
# Length of namelist: 24295
# Length of ACF: 24295
# Length of AAindex: 24295
# Length of binary: 24295
# Length of gpn: 24295
# Length of CKSAAPs: 24295
# Length of PseAAC: 24295
# Length of ASA: 23925
# Length of SS: 23925
# Length of BTA: 23925
# Length of pssmframe: 23925

# %%
storage10features('E:/NingLab/object/khib/results/', namelist, ACF, AAindex, binary, gpn, CKSAAPs, PseAAC, ASA, SS, BTA, pssmframe,
                  0)
# Out:
# Q5XIC6_72
# 0
# Q8IUD2_905
# 1
# P45378_73
# 2
# Q15020_294
# 3
# P08048_293
# 4
# Q13561_75
# 5
# O95104_1137
# 6
# P05426_31
# 7
# P40189_903
# 8
# Q9H0E3_1037
# 9
# F1LU71_313
# 10
# O75976_318
# 11
# A0A0G2QC21_661
# 12
# P82675_272
# 13
# P17676_316
# 14
# Q63258_583
# 15
# O60229_287
# 16
# Q07009_10
# 17
# Q8TDM6_1875
# 18
# Q16762_136
# 19
# G3V709_163
# 20
# P52948_595
# 21
# D3ZA84_147
# 22
# O00203_90
# 23
# P08011_5
# 24
# O95347_1146
# 25
# F1MAN8_810
# 26
# M9MMM9_2321
# 27
# P01024_1105
# 28
# Q8WZ42_11535
# 29
# Q6IRK8_73
# 30
# Q03001_5819
# 31
# Q8IY81_386
# 32
# P40227_104
# 33
# Q13435_547
# 34
# Q15386_1027
# 35
# Q9UNF1_71
# 36
# F1M265_259
# 37
# O75694_297
# 38
# G3V7G9_496
# 39
# P46060_183
# 40
# Q9Y2A7_44
# 41
# A0A0G2JU96_608
# 42
# F1LRI5_2579
# 43
# Q96J01_133
# 44
# Q8NDV3_922
# 45
# Q13439_1653
# 46
# A0A0G2K5T1_1135
# 47
# Q6VY07_426
# 48
# F1LNC3_544
# 49
# Q5QD51_1644
# 50
# Q9Y490_673
# 51
# D3ZCL8_99
# 52
# G3V6A8_2373
# 53
# Q15155_871
# 54
# D4A0F3_146
# 55
# A6KNE7_9
# 56
# D4A8H8_950
# 57
# Q4G064_279
# 58
# Q499N5_238
# 59
# Q8WZ42_32931
# 60
# Q15149_1996
# 61
# Q641Y8_172
# 62
# G3V6D8_635
# 63
# Q92667_588
# 64
# Q8N806_45
# 65
# Q8WZ42_1798
# 66
# Q14573_324
# 67
# F1LM42_2414
# 68
# P18395_207
# 69
# Q63616_490
# 70
# Q9UPT5_586
# 71
# A0A0G2JVW6_772
# 72
# Q9BUL5_95
# 73
# O75674_21
# 74
# Q9HD45_440
# 75
# O60841_367
# 76
# F1LNS0_961
# 77
# O14617_815
# 78
# Q5SSJ5_208
# 79
# O75844_273
# 80
# P53367_306
# 81
# Q8N183_152
# 82
# Q66H32_78
# 83
# P49588_65
# 84
# Q13813_1543
# 85
# P53804_1025
# 86
# M9MMM9_1865
# 87
# Q9ULU4_265
# 88
# Q68FX3_461
# 89
# Q5VT79_192
# 90
# Q64560_791
# 91
# A0A0G2K0I6_119
# 92
# F1M949_1761
# 93
# Q63584_92
# 94
# P02301_24
# 95
# Q5T8P6_103
# 96
# Q15643_1121
# 97
# D4ACB8_225
# 98
# O95379_184
# 99
# Q9H583_1126
# 100
# A4GW50_434
# 101
# P61764_23
# 102
# Q9BZF9_1042
# 103
# O88989_79
# 104
# O75131_528
# 105
# A0A0G2K5P5_986
# 106
# E9PTE1_239
# 107
# Q13617_677
# 108
# Q9BRK5_239
# 109
# A4GW50_123
# 110
# G3V9M6_138
# 111
# F1LM42_2362
# 112
# Q8WZ42_3062
# 113
# P35249_13
# 114
# Q6IN22_311
# 115
# P55265_384
# 116
# F1LRE1_2
# 117
# Q5RKI1_178
# 118
# A0A0G2K6S9_146
# 119
# D3ZRN5_132
# 120
# O75116_471
# 121
# P02563_413
# 122
# G3V796_26
# 123
# Q7Z3J3_397
# 124
# P30622_435
# 125
# O15162_128
# 126
# A0A0G2JV57_51
# 127
# F8WFR6_74
# 128
# A0A0G2JU96_1748
# 129
# Q96TA2_708
# 130
# Q8IX12_671
# 131
# D3ZXY9_28
# 132
# A0A0G2QC21_109
# 133
# Q5T1M5_712
# 134
# Q9BYD6_52
# 135
# Q14978_593
# 136
# Q96E29_299
# 137
# P05198_209
# 138
# Q4KM49_246
# 139
# D3ZQ59_215
# 140
# D3ZBS2_116
# 141
# Q9BTC0_886
# 142
# Q86SZ2_109
# 143
# P02564_1221
# 144
# B0BNC0_7
# 145
# Q13813_2127
# 146
# P43246_301
# 147
# P21399_455
# 148
# Q14953_254
# 149
# Q8WZ42_2847
# 150
# F1M9C8_220
# 151
# Q66H91_449
# 152
# F1MA36_291
# 153
# B1WBY1_459
# 154
# A0A0G2JZM8_1254
# 155
# D3ZHI8_297
# 156
# Q4KLL7_55
# 157
# Q9BRR8_641
# 158
# P35659_191
# 159
# P07900_116
# 160
# Q969S9_57
# 161
# P07942_1384
# 162
# Q14204_3950
# 163
# Q8WZ42_8399
# 164
# Q96JB5_95
# 165
# Q68FX4_224
# 166
# Q9NZM1_2017
# 167
# P46782_59
# 168
# P78347_582
# 169
# D3ZYL2_588
# 170
# G3V7L1_1334
# 171
# Q9Y4L1_774
# 172
# A0A0G2K1X6_3879
# 173
# A0A140UHW9_1162
# 174
# Q6P136_910
# 175
# B5DEH0_389
# 176
# Q9UBL3_357
# 177
# Q9NQ55_154
# 178
# Q9Y6A9_156
# 179
# P02564_106
# 180
# Q2TA68_79
# 181
# B2RYN1_15
# 182
# O00370_1249
# 183
# Q9H4A4_260
# 184
# F1M2P8_101
# 185
# Q9UPM8_748
# 186
# Q96N66_136
# 187
# B2GV14_483
# 188
# Q6IRK8_1949
# 189
# A0A0G2JUV4_230
# 190
# P04764_394
# 191
# P61011_496
# 192
# Q99590_51
# 193
# Q13347_185
# 194
# O75152_518
# 195
# P48634_27
# 196
# Q96BQ5_251
# 197
# B2GUZ5_178
# 198
# Q99797_50
# 199
# F1MA36_422
# 200
# Q16181_387
# 201
# P16435_167
# 202
# Q9H2U2_105
# 203
# P40227_359
# 204
# Q5XI21_55
# 205
# A0A0G2K0F5_853
# 206
# Q9UGC7_306
# 207
# B1WBY9_382
# 208
# Q2KN99_590
# 209
# Q09666_1322
# 210
# A6JLJ1_47
# 211
# P52597_98
# 212
# P11388_276
# 213
# Q96I24_173
# 214
# A0A096MIY2_285
# 215
# Q8N9V7_1387
# 216
# B5DF91_171
# 217
# Q01970_82
# 218
# Q5XI19_326
# 219
# Q9UDT6_39
# 220
# Q8N3U4_714
# 221
# Q96EY1_175
# 222
# A0A0H2UHZ6_437
# 223
# P0C1X8_568
# 224
# B5DEZ4_532
# 225
# O00203_281
# 226
# P30084_101
# 227
# Q9Y4E1_469
# 228
# O75821_103
# 229
# O60287_585
# 230
# P78312_340
# 231
# P56741_1107
# 232
# Q92538_717
# 233
# A0A0G2JU96_5147
# 234
# A0A1W2Q659_872
# 235
# Q13217_412
# 236
# Q6P2Q9_2034
# 237
# Q8WZ42_15313
# 238
# Q15459_741
# 239
# D3ZQM0_497
# 240
# Q13136_1032
# 241
# P07814_535
# 242
# D4ACS0_298
# 243
# Q09666_5591
# 244
# Q13813_1783
# 245
# Q14203_398
# 246
# Q14683_310
# 247
# P53999_97
# 248
# P61980_411
# 249
# P36776_234
# 250
# M0RBZ7_61
# 251
# Q8WVM8_431
# 252
# D3ZM91_425
# 253
# Q9UGI8_78
# 254
# P02794_158
# 255
# P35467_32
# 256
# Q6AYG3_437
# 257
# P28288_53
# 258
# Q4QQV6_308
# 259
# A0A0G2K9I6_206
# 260
# A0A140TAI1_74
# 261
# D3ZC56_7069
# 262
# D3ZYL2_43
# 263
# P35222_345
# 264
# F1MAA3_135
# 265
# P37397_172
# 266
# P01024_1071
# 267
# F1MAM6_1749
# 268
# P13861_294
# 269
# Q4V7D3_394
# 270
# D3ZEY0_319
# 271
# A0A0G2JU96_2910
# 272
# A0A0G2JX67_689
# 273
# A0A0G2JU96_4195
# 274
# F1LMC2_2293
# 275
# F1M949_354
# 276
# Q13435_451
# 277
# O00410_249
# 278
# Q8N163_667
# 279
# P49327_1158
# 280
# Q561S0_301
# 281
# Q2M3X9_154
# 282
# P48723_390
# 283
# P49750_2067
# 284
# A0A0G2K5L6_675
# 285
# Q32PX9_285
# 286
# P47875_151
# 287
# F1MAN8_3104
# 288
# Q505J9_165
# 289
# P54652_542
# 290
# D3ZCL8_695
# 291
# Q6WCQ1_19
# 292
# P30622_24
# 293
# O15067_1051
# 294
# Q53EZ4_29
# 295
# Q712J3_259
# 296
# Q8WXH0_2559
# 297
# Q12933_364
# 298
# P52565_200
# 299
# Q8WZ42_19446
# 300
# Q9Y265_168
# 301
# P02563_1196
# 302
# Q6ZQQ6_2134
# 303
# F1M0V4_1277
# 304
# Q6PCU4_89
# 305
# A0A0G2K5P8_48
# 306
# A0A0G2K6S9_68
# 307
# Q9Y305_43
# 308
# Q15393_1015
# 309
# Q9UQ88_446
# 310
# Q8TAT6_307
# 311
# P52701_1319
# 312
# O60826_250
# 313
# M0R8A4_142
# 314
# B2RYB3_194
# 315
# Q5U2U3_499
# 316
# Q99798_144
# 317
# M0RDD8_276
# 318
# Q9EQZ1_98
# 319
# Q9ULH0_291
# 320
# P32198_455
# 321
# A0A0G2JVH4_572
# 322
# O75116_1350
# 323
# A0A0G2JZ73_267
# 324
# D4AEI5_52
# 325
# Q568Z6_159
# 326
# A0A0G2K542_396
# 327
# Q9H307_572
# 328
# D4A678_2369
# 329
# Q9NZ63_80
# 330
# Q16881_274
# 331
# P53041_222
# 332
# A0A0G2JSS9_271
# 333
# A0A0G2JZE6_12
# 334
# Q9GZR2_178
# 335
# A0A0G2JVH4_670
# 336
# Q99439_174
# 337
# A0A0G2K9R9_916
# 338
# A0A0G2K405_334
# 339
# O14974_984
# 340
# Q14247_336
# 341
# Q96I24_277
# 342
# Q9BRT6_30
# 343
# Q13867_405
# 344
# P12236_295
# 345
# Q93079_24
# 346
# Q03001_2193
# 347
# B4F7C9_565
# 348
# Q63797_236
# 349
# B1A2U8_362
# 350
# P01024_1111
# 351
# D3ZRN3_292
# 352
# G3V9Z3_341
# 353
# F1M3G7_1714
# 354
# O94851_1650
# 355
# Q9BZ29_542
# 356
# Q7L2E3_9
# 357
# Q9WVE9_991
# 358
# P15924_167
# 359
# O35889_1244
# 360
# M0R402_75
# 361
# P41250_510
# 362
# P21283_21
# 363
# F1LN42_1665
# 364
# D4ADN6_425
# 365
# Q15459_495
# 366
# E9PTE1_1827
# 367
# A0A0G2JXM0_491
# 368
# Q52KK3_296
# 369
# Q5M7T5_403
# 370
# P61758_52
# 371
# Q7Z4V5_382
# 372
# Q15431_776
# 373
# P07384_650
# 374
# Q00688_157
# 375
# Q7L5N1_276
# 376
# O60841_328
# 377
# A0A0G2K1N3_114
# 378
# Q9NTJ3_1280
# 379
# Q5FVM2_243
# 380
# Q69YQ0_796
# 381
# P24155_165
# 382
# Q99541_380
# 383
# Q99376_242
# 384
# A0A0G2JWK7_78
# 385
# Q8WZ42_10922
# 386
# Q92544_109
# 387
# Q9UNQ2_166
# 388
# Q63530_55
# 389
# A0A140TAI3_172
# 390
# B5DFM8_85
# 391
# A0A0G2K3W1_1061
# 392
# Q5U316_21
# 393
# D3ZWU1_500
# 394
# D3ZVB7_256
# 395
# P53804_1571
# 396
# Q9UKY7_76
# 397
# G3V7G0_133
# 398
# Q15738_263
# 399
# Q9Y2A7_12
# 400
# Q96KR7_76
# 401
# G3V6E1_562
# 402
# Q4V7F3_139
# 403
# Q01469_133
# 404
# D3ZQ57_1145
# 405
# Q8TCS8_289
# 406
# Q8WZ42_4976
# 407
# Q9Y4I1_1157
# 408
# P17174_20
# 409
# Q5U2U0_144
# 410
# P05067_496
# 411
# Q9Y618_1210
# 412
# Q6ZXV5_630
# 413
# P40763_551
# 414
# P53987_45
# 415
# D4A6A2_96
# 416
# Q68CQ4_389
# 417
# P30876_730
# 418
# Q86V48_348
# 419
# A6KI11_102
# 420
# Q12965_798
# 421
# Q9NQW6_563
# 422
# Q9Y463_54
# 423
# Q62733_202
# 424
# Q13123_501
# 425
# Q8IXB1_424
# 426
# B5DFK6_342
# 427
# O75937_236
# 428
# O60749_412
# 429
# Q13601_319
# 430
# P47895_16
# 431
# F1LP30_245
# 432
# P25445_201
# 433
# Q9UJX2_313
# 434
# M0RAI4_471
# 435
# Q9ER30_360
# 436
# P06737_539
# 437
# Q9H2U1_778
# 438
# F1LTF8_1123
# 439
# Q06203_62
# 440
# A0A0H2UHF9_272
# 441
# P49792_798
# 442
# Q14974_871
# 443
# Q6P2Q9_1898
# 444
# Q9ULX6_537
# 445
# Q9UPN3_3221
# 446
# P38571_76
# 447
# Q92922_750
# 448
# Q712J3_635
# 449
# A0A0G2JYW3_158
# 450
# O75643_1883
# 451
# P13984_193
# 452
# D4A054_182
# 453
# Q92621_1977
# 454
# P49411_333
# 455
# Q8NEJ9_131
# 456
# O15067_59
# 457
# Q5XIE0_246
# 458
# P30101_104
# 459
# F1LSA8_1896
# 460
# D3ZJR1_55
# 461
# Q9Y2D5_654
# 462
# Q8TE73_3119
# 463
# F1LSA8_1137
# 464
# O35264_166
# 465
# Q14839_1528
# 466
# O75367_301
# 467
# Q9H2G2_1163
# 468
# D4AAR7_761
# 469
# P22314_43
# 470
# G3V965_124
# 471
# P02786_382
# 472
# P48960_546
# 473
# O95182_80
# 474
# M0RC57_272
# 475
# Q07984_58
# 476
# A2RRP1_1828
# 477
# D3ZFR9_136
# 478
# P14923_149
# 479
# D3ZBN0_181
# 480
# Q91V33_96
# 481
# D3Z802_757
# 482
# A0JN29_117
# 483
# Q13586_246
# 484
# Q9H0E9_1109
# 485
# P16086_214
# 486
# P68101_123
# 487
# Q9UIL1_155
# 488
# Q00341_286
# 489
# Q6MZM0_613
# 490
# P18886_457
# 491
# Q96A05_118
# 492
# Q02218_324
# 493
# Q5CZC0_502
# 494
# F1LW91_2034
# 495
# Q6P4Q7_104
# 496
# D3Z9Z0_616
# 497
# Q8NFC6_1514
# 498
# A0A0G2K6U1_529
# 499
# Q9GZU8_74
# 500
# O15226_233
# 501
# G3V7L9_1048
# 502
# Q92538_1105
# 503
# Q99459_598
# 504
# Q9H2G2_811
# 505
# P36776_156
# 506
# A6J3F9_285
# 507
# Q06210_594
# 508
# Q2TA68_154
# 509
# O94973_426
# 510
# P06756_923
# 511
# Q9Y608_163
# 512
# Q9HD20_1035
# 513
# Q9HD26_184
# 514
# Q5RKI5_1248
# 515
# A0A0G2JU89_1782
# 516
# F1M4I1_176
# 517
# Q13813_2195
# 518
# A0A0G2K484_1899
# 519
# A1L130_74
# 520
# Q6AY02_24
# 521
# Q5RK00_100
# 522
# B4F7E8_478
# 523
# Q9UHX1_34
# 524
# G3V9J7_807
# 525
# A0A140TAB6_328
# 526
# P15924_1820
# 527
# A0A0G2JW70_106
# 528
# Q8WZ42_19975
# 529
# Q7L2H7_227
# 530
# Q8WZ42_5437
# 531
# Q92945_448
# 532
# Q4V7F2_140
# 533
# Q15054_312
# 534
# Q9BRT6_3
# 535
# D3ZLS5_2584
# 536
# Q9BZF9_1350
# 537
# P11177_129
# 538
# A0A0G2K9H3_468
# 539
# Q5CZC0_4851
# 540
# A0A0G2JT68_750
# 541
# P26641_220
# 542
# Q12965_652
# 543
# A0A0H2UHV4_917
# 544
# P05023_156
# 545
# G3V8G2_461
# 546
# Q8N752_111
# 547
# Q7L576_121
# 548
# Q6P3V9_406
# 549
# Q63312_730
# 550
# A0A0G2K5C6_1326
# 551
# Q505J8_111
# 552
# Q9UNX4_748
# 553
# Q08945_67
# 554
# P35565_284
# 555
# P51003_504
# 556
# P10412_26
# 557
# P49840_260
# 558
# Q14980_2005
# 559
# Q16881_38
# 560
# O14818_236
# 561
# D3ZA69_102
# 562
# Q14244_486
# 563
# Q8N9V7_1558
# 564
# A6IEC6_255
# 565
# P07948_271
# 566
# Q14839_1529
# 567
# Q92665_69
# 568
# A0A0G2K4R1_357
# 569
# Q1JU68_1291
# 570
# O43318_172
# 571
# F1LZW6_546
# 572
# Q9Y520_2159
# 573
# Q6NZI2_260
# 574
# Q96TA1_123
# 575
# Q5RK19_38
# 576
# Q09666_4731
# 577
# P27008_325
# 578
# Q14914_328
# 579
# Q5CZC0_2910
# 580
# Q6P9X2_163
# 581
# P50475_793
# 582
# Q92841_168
# 583
# B1WC16_517
# 584
# D4A054_233
# 585
# Q9C0C9_283
# 586
# Q15155_685
# 587
# P0DMV9_248
# 588
# Q2Y0W8_418
# 589
# O00566_444
# 590
# O43264_449
# 591
# F1M5V2_126
# 592
# R9PXS4_195
# 593
# A0A0G2K3B0_196
# 594
# Q96A33_157
# 595
# P09874_1000
# 596
# A0A2H2GPM9_109
# 597
# O95104_803
# 598
# D4A8D5_593
# 599
# Q5XIM9_342
# 600
# Q15020_891
# 601
# Q9Y678_389
# 602
# B1AJZ9_840
# 603
# P20762_202
# 604
# O60763_928
# 605
# P20908_1542
# 606
# D3ZC56_2987
# 607
# Q12965_291
# 608
# P00568_148
# 609
# P11388_1516
# 610
# P61203_170
# 611
# Q14554_514
# 612
# Q14651_580
# 613
# O75083_81
# 614
# Q96GK7_288
# 615
# Q6AXV4_306
# 616
# F1M3D3_383
# 617
# Q6AYJ9_287
# 618
# Q14573_1748
# 619
# O75323_58
# 620
# Q5XID1_224
# 621
# Q8NE71_203
# 622
# P49755_213
# 623
# Q8WXH0_3709
# 624
# Q9Y4W2_182
# 625
# Q9NQR8_32
# 626
# Q6ZR08_2568
# 627
# A0A0G2K2R2_207
# 628
# Q9H223_535
# 629
# Q5C9Z4_675
# 630
# P20810_382
# 631
# F1M853_64
# 632
# P17252_29
# 633
# O75844_165
# 634
# Q14789_913
# 635
# Q01082_714
# 636
# Q8TE59_526
# 637
# Q8WTT2_18
# 638
# M9MMM9_1581
# 639
# P38606_165
# 640
# P62494_209
# 641
# P28370_433
# 642
# A0A0G2JSS9_61
# 643
# Q4V8B7_323
# 644
# P11310_26
# 645
# Q505J8_321
# 646
# P80723_184
# 647
# G3V7Q6_165
# 648
# O43823_460
# 649
# F1M9N4_271
# 650
# A0A0G2JX77_912
# 651
# P78371_342
# 652
# O60229_2143
# 653
# D3ZSG3_6
# 654
# Q4V328_195
# 655
# Q07803_456
# 656
# Q8TE59_963
# 657
# P42224_173
# 658
# Q6WCQ1_174
# 659
# Q96BY6_1312
# 660
# Q9BTC0_518
# 661
# Q9NWS8_92
# 662
# P63000_184
# 663
# G3V6D9_90
# 664
# P49189_461
# 665
# D3Z9Z0_449
# 666
# D3ZHV1_215
# 667
# A0A0G2JSZ5_92
# 668
# Q92841_417
# 669
# Q6IRJ7_208
# 670
# Q9NRY5_405
# 671
# F1M7B8_724
# 672
# O14672_251
# 673
# F1LPQ9_480
# 674
# P62191_326
# 675
# F1LQ09_105
# 676
# Q68FW7_133
# 677
# P13797_452
# 678
# O14646_1606
# 679
# P47860_775
# 680
# Q99PV2_332
# 681
# P61201_190
# 682
# F1LPH1_322
# 683
# P38571_215
# 684
# Q6P6V0_440
# 685
# A0A0G2K1M2_65
# 686
# P11532_2184
# 687
# A0A0H2UHQ0_79
# 688
# P62260_123
# 689
# Q02759_286
# 690
# P62982_27
# 691
# Q63041_1015
# 692
# M0R557_2862
# 693
# O95425_1609
# 694
# Q9ERB4_2219
# 695
# Q8WTT2_40
# 696
# Q8IXH7_229
# 697
# A0A0G2K1Y8_1660
# 698
# D3ZXK3_2745
# 699
# F1LUA1_317
# 700
# D3ZC56_5147
# 701
# O14964_283
# 702
# D4A7X7_556
# 703
# Q8NFC6_520
# 704
# Q9NQW6_908
# 705
# P35284_79
# 706
# Q9UIJ7_57
# 707
# D4A133_473
# 708
# Q8NDV3_806
# 709
# Q02809_54
# 710
# Q8TDY2_398
# 711
# D4A054_1655
# 712
# G3V798_277
# 713
# D4A1Q2_547
# 714
# Q96ST3_1261
# 715
# Q66HA8_475
# 716
# D3ZC56_1263
# 717
# D4A7R0_399
# 718
# G3V624_447
# 719
# Q6TXG7_133
# 720
# Q9C0C2_1466
# 721
# P15800_402
# 722
# G3V8B0_1923
# 723
# Q9UQE7_935
# 724
# P17858_444
# 725
# P07199_47
# 726
# G3V6A8_757
# 727
# P14209_151
# 728
# B1WC16_204
# 729
# P42345_2171
# 730
# Q6AXQ0_201
# 731
# Q5VW32_401
# 732
# O94906_395
# 733
# A0A0G2K9Q3_742
# 734
# O75369_976
# 735
# P51398_134
# 736
# O60826_545
# 737
# A6KI11_19
# 738
# Q8WZ42_4793
# 739
# Q8NCU8_39
# 740
# B1WBY1_493
# 741
# Q6MZM0_849
# 742
# Q56UN5_610
# 743
# M0RC54_1020
# 744
# Q8NE71_176
# 745
# D3ZD97_754
# 746
# F1LMC7_156
# 747
# P11030_83
# 748
# Q29RF7_750
# 749
# A0A0G2K0X9_1020
# 750
# D3ZEY0_267
# 751
# P11532_2294
# 752
# Q15428_88
# 753
# Q8WZ42_4898
# 754
# A0A0G2JTW5_833
# 755
# P57088_221
# 756
# Q9Y4D1_622
# 757
# Q14152_672
# 758
# Q9UNX3_41
# 759
# D4A0B4_582
# 760
# Q9ULU4_637
# 761
# F1LN92_96
# 762
# Q8NE86_150
# 763
# F1M775_476
# 764
# A0A0G2JZM8_47
# 765
# Q6P2Q9_477
# 766
# P62959_83
# 767
# A0A0G2JUP3_1755
# 768
# Q2PZI1_595
# 769
# Q7L1Q6_52
# 770
# D4A772_542
# 771
# P40227_502
# 772
# Q71UM5_82
# 773
# Q8NBZ0_13
# 774
# Q6IRK8_1167
# 775
# Q9ERB4_260
# 776
# Q4V8J6_249
# 777
# Q6P747_496
# 778
# P80188_162
# 779
# Q92805_748
# 780
# D3ZC56_3569
# 781
# Q9BWM7_222
# 782
# Q9UNF0_317
# 783
# P18886_459
# 784
# Q6PGP7_971
# 785
# Q5U2Q5_733
# 786
# A0A0G2K700_499
# 787
# P14735_217
# 788
# A0A0G2JW97_382
# 789
# P46821_1232
# 790
# P58876_28
# 791
# D3ZUC9_297
# 792
# P16617_230
# 793
# Q14683_690
# 794
# Q8CGS4_43
# 795
# D4ACS0_2
# 796
# A6IAX1_233
# 797
# A1L122_78
# 798
# P21333_2119
# 799
# F1M949_1075
# 800
# A0A1W2Q628_281
# 801
# Q99733_282
# 802
# Q14789_1500
# 803
# Q8TBC4_207
# 804
# O60610_1252
# 805
# P41252_371
# 806
# Q13045_671
# 807
# Q00341_90
# 808
# P02563_763
# 809
# O00566_256
# 810
# F1LUA1_1151
# 811
# A0A0A0MXU4_258
# 812
# B1WBS1_653
# 813
# Q5BK18_467
# 814
# A0A140TAH1_339
# 815
# Q15431_774
# 816
# Q66HL2_107
# 817
# P26641_241
# 818
# Q13523_428
# 819
# A0A0G2K151_319
# 820
# F1LRJ9_154
# 821
# P54868_83
# 822
# A0A0G2JYA3_512
# 823
# Q9BZZ5_302
# 824
# Q99590_778
# 825
# Q15021_215
# 826
# P26038_339
# 827
# A0A0H2UHI5_255
# 828
# E9PU01_1739
# 829
# Q96AY3_212
# 830
# Q96KR7_337
# 831
# Q02880_1304
# 832
# A6JPR7_476
# 833
# Q6S399_3950
# 834
# O15118_576
# 835
# O14617_744
# 836
# Q8WZ42_11238
# 837
# P48723_296
# 838
# Q8TE59_621
# 839
# Q07936_249
# 840
# P22062_221
# 841
# Q14789_2017
# 842
# B5DEY8_139
# 843
# Q3B7D1_168
# 844
# Q14839_1780
# 845
# A0A0G2QC38_503
# 846
# P37235_50
# 847
# D3ZHR6_251
# 848
# P14923_283
# 849
# P02786_439
# 850
# Q7TMA9_749
# 851
# D3ZHI8_781
# 852
# P70541_435
# 853
# A0A0G2JUP3_1978
# 854
# O14657_150
# 855
# D4AA54_1290
# 856
# Q8WVX9_419
# 857
# Q9Y4E1_318
# 858
# Q9P2D0_784
# 859
# Q5RKI5_296
# 860
# P62260_244
# 861
# D3Z8C7_615
# 862
# D3ZVG3_138
# 863
# Q7KZ85_410
# 864
# Q6AYB5_100
# 865
# Q9UBQ5_171
# 866
# Q9NZI8_566
# 867
# Q6NUK1_90
# 868
# A0A0G2JSV3_197
# 869
# Q9UIG0_281
# 870
# D3ZH41_249
# 871
# F1LQP9_59
# 872
# Q8WYA0_95
# 873
# Q6NX65_184
# 874
# M0RD40_109
# 875
# Q6IN39_655
# 876
# P27008_108
# 877
# Q66HD3_305
# 878
# F1M0V4_18
# 879
# A0A0G2KB58_870
# 880
# P61011_178
# 881
# P07910_204
# 882
# A0A0G2K1Y8_662
# 883
# Q8WZ42_4669
# 884
# P21333_1372
# 885
# D4AE79_8
# 886
# D4A0B4_139
# 887
# O15327_489
# 888
# Q13596_214
# 889
# F1M3H3_3275
# 890
# D3ZZ00_148
# 891
# A0A0G2JU83_330
# 892
# Q8IWA4_134
# 893
# Q8WZ42_2330
# 894
# Q9HAV7_50
# 895
# A0A0G2K513_177
# 896
# Q9Y4I1_578
# 897
# Q8IX12_656
# 898
# Q5JRA6_412
# 899
# Q9NX58_308
# 900
# G3V9R9_514
# 901
# Q64524_17
# 902
# Q8TDM6_1645
# 903
# M0RC54_588
# 904
# A0A0G2K0F5_185
# 905
# P16403_196
# 906
# A0A0G2K5L6_1454
# 907
# Q9P2J5_988
# 908
# D4A6E3_347
# 909
# Q561S0_248
# 910
# F1M4I1_345
# 911
# Q92665_248
# 912
# P14735_663
# 913
# P11348_189
# 914
# D3Z9L0_177
# 915
# Q5W0V3_195
# 916
# D3Z8I4_229
# 917
# Q5RKI1_100
# 918
# Q09666_3811
# 919
# P34932_697
# 920
# O95425_1366
# 921
# Q13618_651
# 922
# D3ZU52_64
# 923
# Q5XI34_292
# 924
# Q4QQV6_203
# 925
# P53534_552
# 926
# D4A8Y1_203
# 927
# D3ZFC6_139
# 928
# P62083_179
# 929
# P23514_656
# 930
# Q5T1M5_290
# 931
# Q9BUL5_369
# 932
# A0A0G2JXJ7_136
# 933
# D4A054_2198
# 934
# Q66HF1_15
# 935
# P01893_82
# 936
# Q5T1M5_249
# 937
# P38656_37
# 938
# Q8WXF1_184
# 939
# F1MAA7_1286
# 940
# D3ZB30_421
# 941
# Q63570_174
# 942
# B2RZ79_161
# 943
# Q4G017_473
# 944
# P11182_202
# 945
# A0A0H2UHE5_356
# 946
# D4A133_621
# 947
# Q6ZR08_2427
# 948
# F1LTF8_1801
# 949
# Q9NX62_235
# 950
# P30405_160
# 951
# D3ZZ68_641
# 952
# P10959_467
# 953
# P11182_265
# 954
# P02564_1485
# 955
# Q93009_874
# 956
# A0A0G2K3V4_585
# 957
# Q9Y2W2_10
# 958
# Q13443_648
# 959
# Q13045_681
# 960
# Q14694_702
# 961
# A0A0G2K0X9_707
# 962
# Q63HN8_4402
# 963
# A1L122_352
# 964
# O00159_1047
# 965
# D3ZYS7_50
# 966
# O15042_889
# 967
# Q561S0_52
# 968
# G3V6S2_19
# 969
# Q6IE52_701
# 970
# A0A0G2KB58_1547
# 971
# Q8TDY2_1265
# 972
# F1M775_795
# 973
# Q70UQ0_5
# 974
# D3ZEZ9_522
# 975
# O14672_518
# 976
# Q7TP77_62
# 977
# Q9Y2W1_540
# 978
# Q14554_41
# 979
# D3ZN37_737
# 980
# D4A7R0_551
# 981
# Q15005_40
# 982
# G3V7L1_3272
# 983
# F1LRT9_691
# 984
# D3ZIP3_609
# 985
# Q5JRA6_1341
# 986
# Q96RP9_522
# 987
# P18859_51
# 988
# Q96D46_221
# 989
# O75152_221
# 990
# Q8N1G4_205
# 991
# M0R7S5_1080
# 992
# Q9NVP1_584
# 993
# P35998_11
# 994
# D3ZM14_72
# 995
# Q15075_1190
# 996
# D4A678_1857
# 997
# A6JWG9_367
# 998
# D3Z8G3_1022
# 999
# Q6ZR08_989
# 1000
# Q8WZ42_576
# 1001
# O00154_286
# 1002
# O43681_95
# 1003
# Q9NR30_202
# 1004
# P53365_216
# 1005
# F1M9Q8_45
# 1006
# P48449_546
# 1007
# P99999_54
# 1008
# P25205_557
# 1009
# Q5U1Y3_248
# 1010
# P06737_622
# 1011
# O95470_309
# 1012
# B1A2U8_133
# 1013
# G3V7K1_421
# 1014
# Q96RP9_541
# 1015
# P15170_152
# 1016
# Q02809_626
# 1017
# A0A0G2K9I8_70
# 1018
# Q8N6G6_959
# 1019
# Q566E5_443
# 1020
# Q00839_242
# 1021
# F1LPQ9_275
# 1022
# Q66HA8_750
# 1023
# P20908_1125
# 1024
# A0A096MJS3_464
# 1025
# O94804_916
# 1026
# A0A0H2UHM5_87
# 1027
# A0A0H2UI21_610
# 1028
# F1LQ09_324
# 1029
# A0A140TAA4_81
# 1030
# D3ZE30_91
# 1031
# Q6AYK8_142
# 1032
# A6J8Q9_662
# 1033
# P26373_89
# 1034
# D4A1A5_473
# 1035
# Q58FK9_288
# 1036
# Q9Y2D5_8
# 1037
# P30919_227
# 1038
# P18395_239
# 1039
# Q03001_3898
# 1040
# Q3LXA3_186
# 1041
# P08238_652
# 1042
# A0A0G2K9Q3_872
# 1043
# D3ZAY8_563
# 1044
# Q8TDN6_330
# 1045
# D4A2P1_1023
# 1046
# M0RCY2_82
# 1047
# O14776_756
# 1048
# Q05682_587
# 1049
# Q9Y617_259
# 1050
# O43390_224
# 1051
# A0A0G2JU95_336
# 1052
# Q9BU23_51
# 1053
# Q12965_872
# 1054
# P35433_406
# 1055
# O43824_281
# 1056
# A0A0G2JUP3_2473
# 1057
# F1LZW6_423
# 1058
# Q9Y2W1_551
# 1059
# O00232_268
# 1060
# P30533_107
# 1061
# O35867_727
# 1062
# Q06323_91
# 1063
# P49321_172
# 1064
# D3ZXD2_474
# 1065
# F1LMC2_1967
# 1066
# P46778_35
# 1067
# M0RDJ3_228
# 1068
# D3ZSV9_15
# 1069
# Q13439_1696
# 1070
# Q96JB5_471
# 1071
# Q9H4G0_278
# 1072
# D4A4Z9_785
# 1073
# B2RYP0_27
# 1074
# A0A096MJB3_62
# 1075
# F1MAM6_2347
# 1076
# Q8WXH0_1732
# 1077
# A0A0G2JVX7_43
# 1078
# P51795_109
# 1079
# F1LNS0_254
# 1080
# Q9UHX1_514
# 1081
# O75976_531
# 1082
# A0A0G2JU96_131
# 1083
# A0A0G2KAH2_1173
# 1084
# A0A0G2JY08_351
# 1085
# P51809_220
# 1086
# A0A0G2JU89_3728
# 1087
# M0RD40_91
# 1088
# P46013_1022
# 1089
# O95232_224
# 1090
# Q9ULH0_245
# 1091
# P49750_937
# 1092
# A0A0G2JXR0_68
# 1093
# D3ZT07_17
# 1094
# F1LNH3_412
# 1095
# P02770_337
# 1096
# Q8NE86_180
# 1097
# G3V7G9_559
# 1098
# M0R915_1396
# 1099
# D3ZAS8_888
# 1100
# Q5VYK3_852
# 1101
# D3ZYT8_788
# 1102
# G3V662_947
# 1103
# Q08257_124
# 1104
# F1LX47_436
# 1105
# A2VD09_45
# 1106
# F1M0V4_1565
# 1107
# P06686_352
# 1108
# P52209_375
# 1109
# Q9UIG0_821
# 1110
# B2GV14_340
# 1111
# Q9UQE7_332
# 1112
# Q15643_531
# 1113
# Q5XIM7_69
# 1114
# F1M446_1081
# 1115
# D3ZC56_5563
# 1116
# Q8NC51_346
# 1117
# Q7TP91_244
# 1118
# P06756_439
# 1119
# Q13243_36
# 1120
# F1LSS1_240
# 1121
# B5DEH2_192
# 1122
# A0A0H2UHI2_183
# 1123
# Q9Y6E2_127
# 1124
# O60763_710
# 1125
# P48960_343
# 1126
# Q8WZ42_24389
# 1127
# D4A8D5_502
# 1128
# O14646_1300
# 1129
# P52701_824
# 1130
# Q9UNH7_350
# 1131
# G3V6H2_1749
# 1132
# Q96Q11_107
# 1133
# F1LX28_357
# 1134
# P30520_164
# 1135
# P13667_211
# 1136
# A5YKK6_2093
# 1137
# P22695_231
# 1138
# O75976_1213
# 1139
# E9PU01_192
# 1140
# Q9Z1A6_179
# 1141
# P04692_161
# 1142
# B2GV14_330
# 1143
# M0R660_249
# 1144
# D3ZYT8_1260
# 1145
# D3ZKM9_355
# 1146
# G3V7L1_505
# 1147
# Q8N9V7_318
# 1148
# O75477_286
# 1149
# Q96K83_457
# 1150
# P21399_793
# 1151
# Q96TA2_568
# 1152
# Q5I0H4_68
# 1153
# O60841_98
# 1154
# Q9H4G0_569
# 1155
# A0A0G2K911_126
# 1156
# Q6AXS5_285
# 1157
# P78527_310
# 1158
# Q8IZC6_451
# 1159
# A0A0G2JY08_631
# 1160
# Q92878_1290
# 1161
# A0A0G2K777_668
# 1162
# P48426_395
# 1163
# Q8TDY2_1313
# 1164
# Q64303_65
# 1165
# Q9Z0V5_210
# 1166
# D4A3S8_71
# 1167
# P51608_345
# 1168
# P45973_55
# 1169
# Q9BXP5_669
# 1170
# A0A1B0GWQ1_382
# 1171
# D4A1B9_1019
# 1172
# Q5RKI0_600
# 1173
# F1MAM6_359
# 1174
# Q14204_506
# 1175
# Q62865_278
# 1176
# Q63014_302
# 1177
# Q14008_171
# 1178
# Q9Z2J4_25
# 1179
# Q96QK1_323
# 1180
# O95674_67
# 1181
# Q9Y5L0_236
# 1182
# A0A0G2JUP3_3141
# 1183
# G3V6E1_1564
# 1184
# D3ZDI7_31
# 1185
# O75391_75
# 1186
# P01024_1462
# 1187
# A0A0G2JUP3_4192
# 1188
# Q9ULB4_385
# 1189
# Q5M9G9_574
# 1190
# Q99460_182
# 1191
# Q9QY17_320
# 1192
# P26599_497
# 1193
# Q4R1A4_59
# 1194
# D3ZZ00_151
# 1195
# D3ZZB0_534
# 1196
# G3V9G5_986
# 1197
# Q9HC38_305
# 1198
# F1LNC3_1002
# 1199
# P11530_1238
# 1200
# Q8TDM6_1122
# 1201
# Q03626_171
# 1202
# A0A0G2K571_9
# 1203
# Q12802_2152
# 1204
# Q9Y3A5_226
# 1205
# Q63355_685
# 1206
# Q9NVH1_206
# 1207
# Q6ZQQ6_2121
# 1208
# Q07014_324
# 1209
# M0R6Z9_284
# 1210
# Q9UHR4_57
# 1211
# Q9NUQ3_277
# 1212
# P78312_1101
# 1213
# Q01813_455
# 1214
# Q15907_145
# 1215
# A0A0G2K5C7_630
# 1216
# Q9UKM9_35
# 1217
# F1LMV6_829
# 1218
# Q8WYA0_152
# 1219
# Q4V8H8_6
# 1220
# O43318_528
# 1221
# P80303_212
# 1222
# B2GUZ9_89
# 1223
# P24155_323
# 1224
# Q9UKK3_724
# 1225
# Q9EPF2_69
# 1226
# F1M754_918
# 1227
# D3ZA69_411
# 1228
# Q15393_984
# 1229
# A0A0G2JVP4_356
# 1230
# B5DFK6_1077
# 1231
# D3ZC56_5919
# 1232
# F1M9D6_145
# 1233
# Q9BQG0_498
# 1234
# A0A0G2JU89_1767
# 1235
# Q9Y490_1401
# 1236
# Q63707_109
# 1237
# Q15418_709
# 1238
# P07151_78
# 1239
# Q15084_159
# 1240
# Q5JRA6_1446
# 1241
# B6RK61_970
# 1242
# Q2LAP6_132
# 1243
# Q8WZ42_32207
# 1244
# Q06481_549
# 1245
# A0A0G2JU01_590
# 1246
# Q5CZC0_1262
# 1247
# Q8TE59_395
# 1248
# P62718_21
# 1249
# G3V7I8_1149
# 1250
# Q06481_120
# 1251
# Q08379_46
# 1252
# P21333_278
# 1253
# Q14696_212
# 1254
# Q16543_227
# 1255
# Q12802_1986
# 1256
# O00429_660
# 1257
# M0R3K1_8
# 1258
# A0A0U1RRV5_333
# 1259
# P40938_79
# 1260
# P51946_305
# 1261
# A0A0G2K6S9_145
# 1262
# F1LQP9_78
# 1263
# Q9UI09_53
# 1264
# Q9NUU7_343
# 1265
# Q01831_862
# 1266
# P21533_141
# 1267
# P42696_104
# 1268
# P62241_19
# 1269
# Q9BZF9_1190
# 1270
# P09543_280
# 1271
# O00186_384
# 1272
# Q92616_2634
# 1273
# Q5U312_42
# 1274
# D3ZC84_1777
# 1275
# Q9UNF1_368
# 1276
# P13797_68
# 1277
# Q9H7B2_57
# 1278
# P07948_103
# 1279
# Q99996_2203
# 1280
# Q07157_1472
# 1281
# P20042_14
# 1282
# A0A0G2QC38_488
# 1283
# Q62952_269
# 1284
# P43246_567
# 1285
# D4AB98_254
# 1286
# Q6IRK9_82
# 1287
# Q13907_185
# 1288
# G3V8G2_493
# 1289
# Q8WZ42_27343
# 1290
# Q9BW30_40
# 1291
# Q9UPM8_7
# 1292
# P21333_2631
# 1293
# D3Z802_581
# 1294
# A0A0G2K8K3_289
# 1295
# F1M775_311
# 1296
# B1WC28_147
# 1297
# Q8WTT2_175
# 1298
# P78347_86
# 1299
# O95299_280
# 1300
# G3V662_1059
# 1301
# P02564_129
# 1302
# P52272_218
# 1303
# A0A0G2K428_385
# 1304
# Q6AXS3_200
# 1305
# Q04637_745
# 1306
# G3V796_358
# 1307
# P62993_26
# 1308
# A0A0G2K4D0_164
# 1309
# Q14527_889
# 1310
# Q14683_607
# 1311
# A0A0G2K9H3_143
# 1312
# Q03001_6981
# 1313
# Q86WR0_125
# 1314
# P28331_336
# 1315
# D3ZFQ3_312
# 1316
# P53565_939
# 1317
# D4A510_653
# 1318
# Q3MIF1_130
# 1319
# F1M609_305
# 1320
# Q8IVF2_4985
# 1321
# A0A140TAF0_49
# 1322
# A0A0G2K896_630
# 1323
# G3V667_613
# 1324
# P46821_740
# 1325
# Q96GK7_171
# 1326
# Q7KZI7_754
# 1327
# Q14204_2989
# 1328
# Q14974_211
# 1329
# A0A0H2UHE5_102
# 1330
# O55096_266
# 1331
# F1LMC2_1220
# 1332
# Q9QX80_76
# 1333
# Q9H9J2_318
# 1334
# P34897_356
# 1335
# O95347_898
# 1336
# F1LRE1_196
# 1337
# P34058_402
# 1338
# D3ZAK6_123
# 1339
# A0A0G2JYF7_883
# 1340
# Q13596_107
# 1341
# Q68FR6_52
# 1342
# O60869_42
# 1343
# F6QBA3_323
# 1344
# O35567_483
# 1345
# O60313_941
# 1346
# Q9BTC0_468
# 1347
# P20020_350
# 1348
# P11532_1510
# 1349
# B5DFK6_726
# 1350
# A0A0G2JU96_3059
# 1351
# P15927_138
# 1352
# Q99715_1344
# 1353
# Q9HD20_845
# 1354
# O00370_358
# 1355
# O75179_581
# 1356
# G3V8V6_17
# 1357
# Q86XP3_546
# 1358
# P19338_384
# 1359
# Q8IWJ2_680
# 1360
# Q9Y6N5_280
# 1361
# A0A140TAA4_654
# 1362
# O94925_106
# 1363
# P43278_137
# 1364
# Q9UPN3_6586
# 1365
# O75475_218
# 1366
# Q99575_264
# 1367
# P28838_61
# 1368
# A0A140TAC3_226
# 1369
# P46934_1146
# 1370
# Q8TEQ6_815
# 1371
# Q71LX6_1846
# 1372
# A0A0G2K5A4_595
# 1373
# P53565_937
# 1374
# Q5U316_198
# 1375
# Q8K1Q0_464
# 1376
# P21399_19
# 1377
# Q56A27_707
# 1378
# Q13123_30
# 1379
# Q14677_153
# 1380
# Q86UP2_811
# 1381
# D3ZJR1_634
# 1382
# Q9NYU1_1258
# 1383
# F1M614_60
# 1384
# P16144_654
# 1385
# Q9UNM6_115
# 1386
# P82664_114
# 1387
# Q9UIQ6_865
# 1388
# Q9UNF1_341
# 1389
# F1LRT9_86
# 1390
# P13697_258
# 1391
# D3ZMU3_290
# 1392
# P48509_8
# 1393
# P08962_229
# 1394
# Q03001_3914
# 1395
# O60271_373
# 1396
# F1LM47_244
# 1397
# O14578_3
# 1398
# G3V918_306
# 1399
# P14882_644
# 1400
# Q6P2Q9_774
# 1401
# E9PTJ1_288
# 1402
# F1LNC3_538
# 1403
# O00159_357
# 1404
# Q12802_2230
# 1405
# Q9BTW9_310
# 1406
# Q9WU49_117
# 1407
# D4A1Q2_379
# 1408
# Q96B97_225
# 1409
# O60291_240
# 1410
# Q7TMA9_194
# 1411
# P30740_244
# 1412
# O60291_113
# 1413
# Q4V8E2_43
# 1414
# Q08379_203
# 1415
# P61764_584
# 1416
# A0A0G2JT68_1294
# 1417
# P08758_193
# 1418
# Q96K83_33
# 1419
# Q8WZ42_21011
# 1420
# D3Z881_1190
# 1421
# P61163_81
# 1422
# Q9NT62_11
# 1423
# Q8IY81_322
# 1424
# P01024_1375
# 1425
# P25398_44
# 1426
# B0LPN4_4675
# 1427
# Q9NR33_47
# 1428
# A0A0G2K167_297
# 1429
# Q9C0C2_1000
# 1430
# O96005_199
# 1431
# Q76FK4_966
# 1432
# Q13561_289
# 1433
# Q63083_217
# 1434
# A0A0G2KAE1_334
# 1435
# Q62824_215
# 1436
# D4A702_371
# 1437
# Q712J3_168
# 1438
# B1WC02_392
# 1439
# Q16698_162
# 1440
# Q13616_468
# 1441
# F1M8T4_1157
# 1442
# D3ZQI1_153
# 1443
# Q96TA2_359
# 1444
# Q8IX03_827
# 1445
# Q9Y618_2290
# 1446
# D3ZHV1_304
# 1447
# Q2PZI1_668
# 1448
# Q53EU6_332
# 1449
# P07942_1727
# 1450
# Q96Q11_291
# 1451
# Q9UH65_268
# 1452
# P16086_770
# 1453
# A0A0H2UHZ2_297
# 1454
# A0A0G2K7L0_125
# 1455
# Q6AY18_87
# 1456
# O75531_6
# 1457
# D4A1B9_942
# 1458
# G3V6P2_21
# 1459
# P00441_137
# 1460
# A0A0G2K5L6_1095
# 1461
# O95140_316
# 1462
# Q02127_185
# 1463
# P06576_159
# 1464
# G3V6A8_1848
# 1465
# F1LTX4_348
# 1466
# Q8WZ42_5418
# 1467
# Q9ESS6_506
# 1468
# D3ZLP2_423
# 1469
# Q2Y0W8_227
# 1470
# Q9P289_401
# 1471
# Q9WVK7_28
# 1472
# A0A0G2K761_349
# 1473
# Q5JPH6_284
# 1474
# P18886_164
# 1475
# F1M775_504
# 1476
# Q8WZ42_4532
# 1477
# Q8WUM4_640
# 1478
# A0A096MKD4_621
# 1479
# P46100_1147
# 1480
# A0A0G2K2T6_813
# 1481
# D3ZSG3_343
# 1482
# A0A0G2K0F5_84
# 1483
# Q5PQK2_325
# 1484
# Q9UBF2_7
# 1485
# D4A617_49
# 1486
# Q7Z6Z7_980
# 1487
# Q7KZI7_224
# 1488
# Q09666_4118
# 1489
# Q09666_1305
# 1490
# F1LXD8_130
# 1491
# Q15067_198
# 1492
# Q9ES54_191
# 1493
# A0A140UHW9_872
# 1494
# F1LM55_590
# 1495
# G3V8V3_30
# 1496
# Q8WWY3_401
# 1497
# G3V6E1_370
# 1498
# Q9ULB4_522
# 1499
# A0A1W2Q659_578
# 1500
# P38656_284
# 1501
# A0A0G2JUP0_119
# 1502
# F1MAM6_296
# 1503
# Q6AYJ9_212
# 1504
# Q86UL3_365
# 1505
# A0A140UHW9_375
# 1506
# P51608_249
# 1507
# Q53FA7_203
# 1508
# Q96K83_508
# 1509
# Q7Z3J3_1538
# 1510
# Q9P2E9_1246
# 1511
# Q8IXJ6_338
# 1512
# Q00341_50
# 1513
# F1LSW7_93
# 1514
# D4A2F1_2038
# 1515
# Q09666_3910
# 1516
# Q8WUM4_541
# 1517
# A0A0H2UHS3_200
# 1518
# Q2M3X9_116
# 1519
# P80386_259
# 1520
# Q14008_353
# 1521
# O60437_768
# 1522
# O60488_367
# 1523
# Q9NWU5_112
# 1524
# Q14244_107
# 1525
# D3ZCI6_282
# 1526
# D3ZI16_170
# 1527
# Q01728_291
# 1528
# Q14980_839
# 1529
# P46821_676
# 1530
# Q5SSJ5_497
# 1531
# Q9BPX6_447
# 1532
# A0A0G2JY22_1298
# 1533
# O43747_716
# 1534
# B0BN85_120
# 1535
# D3ZRF8_267
# 1536
# G3V7G9_356
# 1537
# D3ZIC4_878
# 1538
# F1LNF0_403
# 1539
# Q9P2D0_381
# 1540
# O95104_18
# 1541
# Q14008_539
# 1542
# Q9UN76_584
# 1543
# P26368_195
# 1544
# O75533_656
# 1545
# P55263_42
# 1546
# Q08380_554
# 1547
# A0A0G2JVG4_148
# 1548
# G3V7J0_517
# 1549
# D3ZE72_54
# 1550
# Q15435_244
# 1551
# Q66HD0_322
# 1552
# Q14165_247
# 1553
# D3ZT07_22
# 1554
# O75369_1425
# 1555
# A0A0G2JX77_543
# 1556
# O95347_796
# 1557
# F1LR42_128
# 1558
# Q9NP61_489
# 1559
# A0A0G2JU96_1509
# 1560
# A0A0G2JWS2_822
# 1561
# Q5JRX3_251
# 1562
# P18886_274
# 1563
# A0A0G2K930_45
# 1564
# Q9Y265_281
# 1565
# G3V6L9_96
# 1566
# B1WC61_457
# 1567
# Q63HN8_356
# 1568
# P53778_223
# 1569
# P04114_707
# 1570
# Q96TA1_203
# 1571
# Q71LX6_1558
# 1572
# F1LPK7_288
# 1573
# Q8NI27_1528
# 1574
# P04181_392
# 1575
# Q03001_3778
# 1576
# Q6P7P5_308
# 1577
# D3ZSA9_923
# 1578
# Q6P747_185
# 1579
# Q07984_168
# 1580
# P48449_432
# 1581
# Q99996_969
# 1582
# Q01650_422
# 1583
# Q641X8_289
# 1584
# P83731_139
# 1585
# A0A0H2UHQ9_699
# 1586
# Q96KP4_225
# 1587
# P12270_366
# 1588
# Q92609_184
# 1589
# Q16543_108
# 1590
# Q9NWT1_280
# 1591
# Q5XI17_144
# 1592
# O14646_1453
# 1593
# P27708_795
# 1594
# Q00341_590
# 1595
# Q9Y520_2079
# 1596
# F1LSS1_5
# 1597
# Q9H3S7_1439
# 1598
# Q9Y4K0_653
# 1599
# P0C1X8_242
# 1600
# P11166_256
# 1601
# P55160_479
# 1602
# P35579_940
# 1603
# P07602_336
# 1604
# D4A8H8_150
# 1605
# Q92797_909
# 1606
# Q96KR1_356
# 1607
# B4F763_451
# 1608
# Q9Y3A5_151
# 1609
# A0A0H2UHV4_771
# 1610
# G3V6V1_162
# 1611
# Q00765_73
# 1612
# A0A0H2UHV6_104
# 1613
# P07602_519
# 1614
# A0A0G2JSP3_348
# 1615
# A0A0G2JVM2_502
# 1616
# P33176_240
# 1617
# G3V6S3_24
# 1618
# P42285_464
# 1619
# P15800_981
# 1620
# P30622_586
# 1621
# Q02809_546
# 1622
# D3ZAZ0_84
# 1623
# G3V7L9_115
# 1624
# Q9UPN3_3454
# 1625
# Q13045_57
# 1626
# O43169_148
# 1627
# Q9H2G2_1117
# 1628
# A0A140UHW9_1044
# 1629
# P04762_524
# 1630
# D4A5I9_965
# 1631
# P26368_276
# 1632
# P18858_899
# 1633
# Q8TE73_3142
# 1634
# Q9Y6A5_423
# 1635
# A0A0G2JVK4_382
# 1636
# P46940_1185
# 1637
# B2RYJ3_33
# 1638
# O43837_199
# 1639
# Q9UPN3_5025
# 1640
# O60287_233
# 1641
# P46013_2236
# 1642
# Q7Z3C6_149
# 1643
# O94925_656
# 1644
# G3V7L1_2359
# 1645
# Q66HG4_300
# 1646
# A0A0G2K648_32
# 1647
# P09960_195
# 1648
# Q96A65_725
# 1649
# P78312_14
# 1650
# D3ZMN5_737
# 1651
# P22307_385
# 1652
# P46821_1702
# 1653
# P07814_578
# 1654
# P53804_1869
# 1655
# O60524_442
# 1656
# P46977_613
# 1657
# P63244_44
# 1658
# O00159_884
# 1659
# Q15054_153
# 1660
# P13861_263
# 1661
# Q9UP83_544
# 1662
# A0A0H2UI06_296
# 1663
# Q13464_375
# 1664
# Q4V8K2_347
# 1665
# B1A2U8_970
# 1666
# O15061_417
# 1667
# D4A617_378
# 1668
# F1M0V4_562
# 1669
# Q8TEQ6_833
# 1670
# P48634_181
# 1671
# O43395_103
# 1672
# P18583_2166
# 1673
# D4ACK1_1167
# 1674
# Q9Y5Z7_114
# 1675
# Q62780_215
# 1676
# Q9NPG3_100
# 1677
# P05426_234
# 1678
# Q9H3S7_1433
# 1679
# P43243_804
# 1680
# C0HKE8_16
# 1681
# P19105_169
# 1682
# D3ZC56_4462
# 1683
# Q66X93_160
# 1684
# Q9Y608_58
# 1685
# Q14203_135
# 1686
# D3ZZ00_1482
# 1687
# O95218_46
# 1688
# Q66HA8_586
# 1689
# Q99798_323
# 1690
# P58876_121
# 1691
# A0A140TAA4_620
# 1692
# P46821_2237
# 1693
# A0A0H2UI21_261
# 1694
# A0A140TAC3_23
# 1695
# P98175_700
# 1696
# P23514_362
# 1697
# Q9Y5J1_175
# 1698
# D3ZI99_52
# 1699
# D3ZIY3_512
# 1700
# O15438_200
# 1701
# D4A7N1_137
# 1702
# F1M853_320
# 1703
# Q13136_800
# 1704
# Q5VZL5_1206
# 1705
# Q4V7E8_425
# 1706
# P12956_297
# 1707
# A0A0G2K1F3_302
# 1708
# F1M9C9_428
# 1709
# P17252_141
# 1710
# Q5FVN1_144
# 1711
# D3ZN37_893
# 1712
# Q9NTJ3_1267
# 1713
# M9MMM9_1598
# 1714
# Q7Z406_1839
# 1715
# B2RYQ2_69
# 1716
# P11021_620
# 1717
# Q7Z2W4_758
# 1718
# Q9H2P0_169
# 1719
# P85972_133
# 1720
# O43765_69
# 1721
# Q14157_26
# 1722
# P20171_167
# 1723
# D4A3E8_362
# 1724
# O60563_546
# 1725
# O60749_433
# 1726
# Q6P3V9_294
# 1727
# Q96KR7_98
# 1728
# E9PU01_501
# 1729
# Q9P2E9_579
# 1730
# Q10471_192
# 1731
# Q92522_119
# 1732
# A0A0G2K6Y4_31
# 1733
# F1M853_932
# 1734
# F1M8F6_1485
# 1735
# A0A0G2JUP3_6520
# 1736
# A0A140TAA4_151
# 1737
# P23378_842
# 1738
# A0A0G2K2W6_832
# 1739
# P10809_157
# 1740
# A4GW50_47
# 1741
# P04114_287
# 1742
# D3ZHR6_55
# 1743
# Q9UKF6_86
# 1744
# Q13523_936
# 1745
# P14625_508
# 1746
# F1M0V4_554
# 1747
# A0A0H2UI21_381
# 1748
# O15226_420
# 1749
# Q9UKK3_677
# 1750
# Q92797_912
# 1751
# P11387_425
# 1752
# B0BN63_212
# 1753
# F1M3H3_3131
# 1754
# Q15021_1288
# 1755
# Q8TDY2_1106
# 1756
# M9MMM9_1435
# 1757
# Q01831_560
# 1758
# A0A0G2JU96_3984
# 1759
# D4AC23_245
# 1760
# Q9NQV7_690
# 1761
# Q9Y512_280
# 1762
# Q13740_423
# 1763
# D3Z941_323
# 1764
# P29084_142
# 1765
# P49589_497
# 1766
# A0A0G2K9R9_1623
# 1767
# M0R485_317
# 1768
# D3ZLP2_299
# 1769
# Q7KZ85_1155
# 1770
# Q99798_605
# 1771
# Q9Y5K6_102
# 1772
# Q6ZR08_1742
# 1773
# Q9UIG0_1291
# 1774
# G3V8G5_558
# 1775
# Q86VP6_620
# 1776
# M0RC65_13
# 1777
# Q96ST3_1204
# 1778
# Q13423_762
# 1779
# Q7Z4V5_563
# 1780
# Q8CGP1_35
# 1781
# A0A0G2K127_691
# 1782
# O00193_50
# 1783
# M0R671_353
# 1784
# Q9NYU2_54
# 1785
# Q9BYP7_1072
# 1786
# P25815_95
# 1787
# Q8TAT6_116
# 1788
# Q63312_300
# 1789
# Q6P136_530
# 1790
# Q13907_11
# 1791
# P10155_287
# 1792
# Q76FK4_409
# 1793
# Q92598_771
# 1794
# D3ZZ99_530
# 1795
# Q2LAP6_322
# 1796
# P53565_731
# 1797
# Q7L576_287
# 1798
# Q709F0_662
# 1799
# Q9P0I2_43
# 1800
# P48307_216
# 1801
# Q9UHB6_280
# 1802
# P02563_1832
# 1803
# F1LYX9_220
# 1804
# P32198_441
# 1805
# P05503_265
# 1806
# F1M265_965
# 1807
# Q86TM6_63
# 1808
# D3ZUQ2_152
# 1809
# D4AAB5_303
# 1810
# Q5XI78_532
# 1811
# B0BNM1_52
# 1812
# A0A0G2JSZ5_196
# 1813
# Q96ST2_452
# 1814
# P84100_165
# 1815
# Q9R0T3_392
# 1816
# A0JPJ7_180
# 1817
# Q96M83_810
# 1818
# Q9BYX7_61
# 1819
# M0RC54_518
# 1820
# Q7TMA9_174
# 1821
# M0R7S5_922
# 1822
# P46940_1543
# 1823
# Q8WZ42_2568
# 1824
# F1LMV6_1513
# 1825
# O75116_780
# 1826
# G3V9M6_1587
# 1827
# Q68FW7_227
# 1828
# D3ZIL9_319
# 1829
# A6JPR7_324
# 1830
# A0A0G2K8S1_1083
# 1831
# D3ZCS4_1609
# 1832
# Q92973_422
# 1833
# Q05519_241
# 1834
# Q9BSJ8_1023
# 1835
# P35658_938
# 1836
# A6HTJ5_158
# 1837
# A0A0G2K1Y8_1764
# 1838
# P55010_413
# 1839
# D4A5E5_159
# 1840
# Q8IVF2_5101
# 1841
# P33176_448
# 1842
# D3ZEH2_84
# 1843
# P30622_811
# 1844
# D3ZSA9_36
# 1845
# F1M3G7_2689
# 1846
# O60841_747
# 1847
# D4A5H0_237
# 1848
# Q9NRV9_140
# 1849
# A0A0G2K542_497
# 1850
# A0A140TAI8_154
# 1851
# Q09666_5512
# 1852
# Q5VT06_1078
# 1853
# Q13618_610
# 1854
# Q9ESN0_60
# 1855
# P54819_229
# 1856
# O15213_9
# 1857
# Q8WX92_166
# 1858
# G3V8Y5_87
# 1859
# P18583_2206
# 1860
# Q14573_2293
# 1861
# P08238_36
# 1862
# Q5VYK3_502
# 1863
# Q9C0C2_708
# 1864
# A0A0G2KAE1_289
# 1865
# B0BN93_2
# 1866
# Q9UKM7_415
# 1867
# F1M614_2607
# 1868
# Q5U2X7_147
# 1869
# O94804_301
# 1870
# Q63041_624
# 1871
# Q63HN8_412
# 1872
# Q9BZE4_8
# 1873
# Q8WZ42_4700
# 1874
# Q03001_221
# 1875
# Q96I99_128
# 1876
# Q99715_1075
# 1877
# P25445_300
# 1878
# O75027_625
# 1879
# Q5U1W6_69
# 1880
# P84092_304
# 1881
# Q8TDY2_838
# 1882
# P01048_113
# 1883
# O60888_79
# 1884
# F1M7Y3_77
# 1885
# Q9UNF1_175
# 1886
# Q14980_1099
# 1887
# P17844_45
# 1888
# P49590_107
# 1889
# O15213_125
# 1890
# Q9BQG0_341
# 1891
# D3ZEZ9_832
# 1892
# P05198_61
# 1893
# A6KRS3_520
# 1894
# Q712J3_91
# 1895
# Q96T51_653
# 1896
# Q5VZL5_345
# 1897
# O00410_981
# 1898
# Q9NZM3_207
# 1899
# Q8N6G6_126
# 1900
# Q9Z0W5_120
# 1901
# A0A0G2JUV4_86
# 1902
# Q5T0F9_483
# 1903
# P55060_346
# 1904
# Q14980_221
# 1905
# Q9BZF9_1332
# 1906
# Q13428_1220
# 1907
# Q8NBX0_140
# 1908
# Q9H7B2_16
# 1909
# O75369_822
# 1910
# Q62760_27
# 1911
# Q9UKY7_211
# 1912
# P11388_1075
# 1913
# A0A0H2UHZ4_286
# 1914
# F1M8T4_627
# 1915
# O43719_662
# 1916
# Q16537_308
# 1917
# Q9P2E9_341
# 1918
# Q9NYU2_1339
# 1919
# P16086_1148
# 1920
# G3V6S2_594
# 1921
# A0A0H2UHH3_606
# 1922
# A0A1B0GWM7_969
# 1923
# P27694_331
# 1924
# F1MAM6_2397
# 1925
# A0A0G2JUP3_5400
# 1926
# Q9Y305_383
# 1927
# Q09666_4374
# 1928
# Q5CZC0_4319
# 1929
# P11387_137
# 1930
# Q92887_716
# 1931
# Q9NSD9_262
# 1932
# D4A1B9_178
# 1933
# F1LQ48_338
# 1934
# P53618_932
# 1935
# F1M614_2486
# 1936
# Q13813_1984
# 1937
# O95758_14
# 1938
# A0A0G2K5C6_602
# 1939
# A6IMJ6_91
# 1940
# Q8IVF2_832
# 1941
# Q8TC12_194
# 1942
# Q9UPN3_3159
# 1943
# Q8TEA8_2
# 1944
# Q14573_426
# 1945
# Q9UI12_341
# 1946
# Q6AYG3_390
# 1947
# D3ZRN5_108
# 1948
# Q8N9R6_7
# 1949
# Q13439_1392
# 1950
# Q15075_1255
# 1951
# A0A0G2JVN4_1141
# 1952
# P53534_370
# 1953
# Q9UBS4_47
# 1954
# Q9Y3B9_18
# 1955
# A0A0G2JSZ0_573
# 1956
# A0A0H2UHZ6_472
# 1957
# A8MXV4_334
# 1958
# P46100_1600
# 1959
# Q76FK4_729
# 1960
# Q96EP5_194
# 1961
# Q8WZ42_11124
# 1962
# G3V6T1_439
# 1963
# A0A0G2K2M9_2382
# 1964
# Q9UBQ0_173
# 1965
# Q12906_742
# 1966
# A0A0G2JYT1_279
# 1967
# Q9P2R7_205
# 1968
# Q99376_163
# 1969
# F1LM42_3395
# 1970
# G3V670_112
# 1971
# A0A0G2K9J2_86
# 1972
# Q15746_1069
# 1973
# Q9UPN3_4668
# 1974
# D4AAI5_410
# 1975
# F1LMI7_178
# 1976
# Q9NQ55_352
# 1977
# Q96K83_5
# 1978
# Q9H2P0_17
# 1979
# Q9UJS0_576
# 1980
# Q29RF7_229
# 1981
# B2RYN0_343
# 1982
# F1M3G7_1252
# 1983
# D4AC65_206
# 1984
# D3ZZ38_453
# 1985
# Q5XIJ3_320
# 1986
# P06576_225
# 1987
# F1LRB8_289
# 1988
# P27008_700
# 1989
# G3V7L1_1946
# 1990
# Q8WZ42_29032
# 1991
# P15907_241
# 1992
# P52701_453
# 1993
# D3ZBS2_562
# 1994
# Q6MG08_189
# 1995
# Q9BTV4_159
# 1996
# Q14692_762
# 1997
# A0A0G2JU89_4835
# 1998
# D3ZWS0_313
# 1999
# Q86UL3_336
# 2000
# Q6AYJ9_136
# 2001
# Q03001_2694
# 2002
# Q12931_653
# 2003
# Q12824_71
# 2004
# P15559_114
# 2005
# P51398_331
# 2006
# D4A478_126
# 2007
# Q5VZF2_243
# 2008
# Q6P9U8_221
# 2009
# B1WC34_297
# 2010
# D4ACK1_818
# 2011
# Q15075_332
# 2012
# D4A022_980
# 2013
# O75152_472
# 2014
# Q9Y333_8
# 2015
# Q3MHS9_426
# 2016
# Q9BTC0_17
# 2017
# D4A3E8_288
# 2018
# Q92820_235
# 2019
# Q5EBC7_552
# 2020
# Q8WWM7_258
# 2021
# Q32MZ4_762
# 2022
# Q71LX6_2411
# 2023
# F1LSM5_249
# 2024
# O96005_207
# 2025
# Q9NTZ6_349
# 2026
# D3Z802_617
# 2027
# Q15833_128
# 2028
# Q6MG79_1608
# 2029
# M0RDC8_78
# 2030
# Q99459_76
# 2031
# P35237_179
# 2032
# A0A0G2JU89_1769
# 2033
# D3ZTN1_45
# 2034
# Q14444_64
# 2035
# Q8N9I0_57
# 2036
# Q9Y4W6_781
# 2037
# B5DEH0_493
# 2038
# Q03001_5766
# 2039
# Q96EY7_408
# 2040
# O95140_732
# 2041
# F1M124_771
# 2042
# G3V7A6_236
# 2043
# G3V778_403
# 2044
# D4A5I9_326
# 2045
# A0A0G2K5L2_33
# 2046
# D4ACK1_1871
# 2047
# Q5XIP0_206
# 2048
# O00541_581
# 2049
# Q5RKG9_137
# 2050
# P15178_381
# 2051
# D4A9Z6_189
# 2052
# Q63HN8_2426
# 2053
# A2RRP1_377
# 2054
# Q9Y2L6_767
# 2055
# A0A096MJ01_712
# 2056
# E9PU28_109
# 2057
# Q8IZC6_1783
# 2058
# A6HIT6_178
# 2059
# P62753_243
# 2060
# A0A0G2JVW5_513
# 2061
# O43491_420
# 2062
# O43491_26
# 2063
# G3V803_841
# 2064
# F1MAN8_1854
# 2065
# Q9NVP1_458
# 2066
# Q9P2E3_1314
# 2067
# Q29RF7_1041
# 2068
# Q99996_936
# 2069
# Q6QI86_277
# 2070
# Q5CZC0_2977
# 2071
# A6IU83_136
# 2072
# D3ZAM6_64
# 2073
# P38919_15
# 2074
# Q9Y520_902
# 2075
# P04179_154
# 2076
# P05455_116
# 2077
# Q63530_111
# 2078
# P97536_303
# 2079
# Q8WZ42_10512
# 2080
# Q12846_80
# 2081
# Q5U2U0_158
# 2082
# Q14764_612
# 2083
# Q9BRT6_108
# 2084
# A0A0G2K5C7_996
# 2085
# Q96AQ6_544
# 2086
# A0A0G2K174_640
# 2087
# F1M949_1843
# 2088
# Q99426_40
# 2089
# Q8NDV3_188
# 2090
# Q8WXH0_5823
# 2091
# P52481_52
# 2092
# Q12802_2368
# 2093
# Q9UHB6_695
# 2094
# P08134_18
# 2095
# P02563_842
# 2096
# Q5QD51_164
# 2097
# Q03626_1287
# 2098
# Q6PGP7_112
# 2099
# P60983_119
# 2100
# P14923_83
# 2101
# P46013_1761
# 2102
# Q8NDV3_829
# 2103
# F1LML7_525
# 2104
# P97615_163
# 2105
# B2GV24_289
# 2106
# A0A0G2K5T1_454
# 2107
# D3ZX42_442
# 2108
# G3V6D9_282
# 2109
# Q4KLF8_60
# 2110
# Q6IRK8_1964
# 2111
# P06753_218
# 2112
# O60488_148
# 2113
# Q3T1J1_50
# 2114
# Q1JU68_39
# 2115
# P52287_15
# 2116
# Q9UM54_904
# 2117
# Q16851_198
# 2118
# Q09666_3583
# 2119
# P40261_39
# 2120
# Q5VTR2_892
# 2121
# Q7Z406_761
# 2122
# Q6P1S2_188
# 2123
# A0A0G2K6B7_760
# 2124
# B0LPN4_1474
# 2125
# P49792_1808
# 2126
# Q6IRK8_227
# 2127
# Q05682_655
# 2128
# D4A3I4_24
# 2129
# A0A0G2KB58_460
# 2130
# D3Z8C7_191
# 2131
# A0A0G2JU89_3574
# 2132
# P37108_96
# 2133
# F1LQS6_1107
# 2134
# A0A0G2JYF7_926
# 2135
# Q14974_729
# 2136
# P20618_77
# 2137
# A0A0G2K047_473
# 2138
# P29117_195
# 2139
# A6NDY0_91
# 2140
# F6QBA3_247
# 2141
# Q13439_545
# 2142
# Q6ZR08_42
# 2143
# Q8WZ42_2976
# 2144
# D4A318_556
# 2145
# P27008_616
# 2146
# Q14789_1950
# 2147
# Q9NYU1_990
# 2148
# M0R7S5_163
# 2149
# D4AC23_359
# 2150
# Q13098_451
# 2151
# P43686_134
# 2152
# D3ZHV1_349
# 2153
# M0RC54_448
# 2154
# D4A054_330
# 2155
# Q92609_157
# 2156
# Q03001_6657
# 2157
# G3V6A8_665
# 2158
# Q8IWJ2_203
# 2159
# Q5RKI1_260
# 2160
# Q6YN16_406
# 2161
# Q9HD26_167
# 2162
# O15042_553
# 2163
# P01015_39
# 2164
# G3V667_198
# 2165
# B2RYN3_68
# 2166
# A0A0G2JSV3_99
# 2167
# P53999_35
# 2168
# P51114_195
# 2169
# D4AAY3_681
# 2170
# O43920_91
# 2171
# Q9H4M9_193
# 2172
# F1M7X3_338
# 2173
# Q8WXH0_2547
# 2174
# D3ZC56_7118
# 2175
# Q9Y2R4_15
# 2176
# P18614_710
# 2177
# Q52KJ9_231
# 2178
# Q9NYF8_362
# 2179
# P15865_190
# 2180
# P51153_71
# 2181
# Q7L8L6_696
# 2182
# D3Z9Z0_1687
# 2183
# Q9R066_159
# 2184
# Q08379_658
# 2185
# Q66X93_248
# 2186
# A0A0G2JSS9_222
# 2187
# Q1KMD3_201
# 2188
# P54886_504
# 2189
# Q9C0C2_1580
# 2190
# P61160_97
# 2191
# Q4V7E5_237
# 2192
# M9MMM9_2897
# 2193
# G3V6R7_361
# 2194
# Q66HC5_218
# 2195
# P46100_910
# 2196
# A0A0G2K135_557
# 2197
# Q5XKP0_101
# 2198
# Q12996_260
# 2199
# Q9EPB1_415
# 2200
# Q14966_1310
# 2201
# P23457_183
# 2202
# O95140_560
# 2203
# Q99996_1733
# 2204
# Q9NUJ1_132
# 2205
# Q9NVM9_646
# 2206
# B0LPN4_1360
# 2207
# Q02880_1327
# 2208
# Q12906_574
# 2209
# Q8N302_710
# 2210
# Q96BM9_182
# 2211
# A6I4N6_188
# 2212
# Q15075_294
# 2213
# O95347_781
# 2214
# Q7Z2K6_447
# 2215
# Q2PS20_632
# 2216
# Q14118_582
# 2217
# Q02952_1734
# 2218
# Q13601_331
# 2219
# A0A0G2JWE1_112
# 2220
# O75367_248
# 2221
# Q5VZL5_522
# 2222
# A0JN29_116
# 2223
# G3V8B0_503
# 2224
# Q00341_407
# 2225
# Q9Y570_316
# 2226
# T2CB11_224
# 2227
# Q63616_119
# 2228
# O75369_2150
# 2229
# P53365_137
# 2230
# P78527_2001
# 2231
# F1MA36_1947
# 2232
# P34949_407
# 2233
# O00541_568
# 2234
# G3V6E1_19
# 2235
# Q6TUH0_165
# 2236
# A0A0G2K393_153
# 2237
# P52888_303
# 2238
# Q6AXS5_298
# 2239
# O88656_339
# 2240
# Q9R0T3_457
# 2241
# Q9UPN3_3417
# 2242
# F1LRT9_2525
# 2243
# A0A0G2K9R9_1735
# 2244
# D3ZD89_578
# 2245
# Q9NQ48_93
# 2246
# Q9Y2A7_190
# 2247
# P07814_313
# 2248
# Q5M7V8_599
# 2249
# Q9JHB5_279
# 2250
# D3ZC56_1126
# 2251
# P27008_658
# 2252
# Q13464_885
# 2253
# Q3SXM5_81
# 2254
# Q5U302_629
# 2255
# O60229_2071
# 2256
# Q6TUH0_59
# 2257
# Q10471_103
# 2258
# P42285_46
# 2259
# Q9NR30_116
# 2260
# P40222_328
# 2261
# D4A365_1001
# 2262
# Q8N5G2_33
# 2263
# Q8WZ42_13738
# 2264
# Q9H788_392
# 2265
# F1LTX4_676
# 2266
# A0A0H2UI21_11
# 2267
# Q96I24_525
# 2268
# Q96KC8_87
# 2269
# A0A0G2JY11_135
# 2270
# A0A0G2K2C2_618
# 2271
# Q96KP1_923
# 2272
# Q8WUW1_31
# 2273
# Q09666_1777
# 2274
# Q6P2Q9_1344
# 2275
# D4A022_1311
# 2276
# Q5SSJ5_116
# 2277
# P42704_314
# 2278
# A0A0G2K0D7_6
# 2279
# Q4V8J6_282
# 2280
# A0A0G2K9P4_32
# 2281
# P04642_22
# 2282
# P04844_243
# 2283
# Q4KLZ3_149
# 2284
# Q86YT6_997
# 2285
# P26284_182
# 2286
# Q29RF7_359
# 2287
# O60869_143
# 2288
# A0A0G2K3A0_874
# 2289
# Q9BRR8_47
# 2290
# Q9NZM3_70
# 2291
# Q8WZ42_24136
# 2292
# A0A140TAI8_53
# 2293
# G3V9N0_30
# 2294
# Q8WXH0_904
# 2295
# Q68FU7_467
# 2296
# A0A0G2JX77_555
# 2297
# A0A0G2K719_481
# 2298
# Q13428_904
# 2299
# O94979_348
# 2300
# D3ZV82_539
# 2301
# O14730_354
# 2302
# Q9H2P0_408
# 2303
# D3ZQT0_197
# 2304
# A0A0G2K0F5_1856
# 2305
# Q9NTJ3_905
# 2306
# Q8WZ42_14589
# 2307
# Q08945_426
# 2308
# A6KI11_234
# 2309
# Q9Y2R4_578
# 2310
# D3ZUT9_858
# 2311
# Q9Y243_201
# 2312
# D3ZYT8_310
# 2313
# A0A1W2Q628_2641
# 2314
# D3ZV82_232
# 2315
# D3ZAQ0_137
# 2316
# D3ZZ81_326
# 2317
# P41252_887
# 2318
# F1M446_1457
# 2319
# Q4QQT3_474
# 2320
# Q7KZ85_195
# 2321
# O95453_413
# 2322
# A0A0G2JU96_1299
# 2323
# F1LM42_2639
# 2324
# E9PTE1_1847
# 2325
# Q8IVF2_4569
# 2326
# P07942_334
# 2327
# D3ZYT8_1176
# 2328
# F7F588_172
# 2329
# Q14152_591
# 2330
# Q8N4X5_19
# 2331
# A8MQT2_110
# 2332
# P26196_286
# 2333
# Q8TE73_1664
# 2334
# A0A0G2K484_807
# 2335
# D3ZCA0_169
# 2336
# P27881_549
# 2337
# Q6ZT07_993
# 2338
# G3V6E1_73
# 2339
# Q8WZ42_11714
# 2340
# E9PTJ1_479
# 2341
# Q02880_1418
# 2342
# Q9BUL8_183
# 2343
# P19234_198
# 2344
# P35284_205
# 2345
# F8WFR6_331
# 2346
# P70618_267
# 2347
# D3ZN37_1078
# 2348
# D3ZBM3_378
# 2349
# Q15746_1883
# 2350
# Q8CGP2_29
# 2351
# P09960_573
# 2352
# Q14980_1821
# 2353
# A0A1W2Q628_631
# 2354
# Q6PKG0_936
# 2355
# Q8N302_700
# 2356
# Q7TS56_16
# 2357
# Q14690_66
# 2358
# P30084_115
# 2359
# D3ZK34_70
# 2360
# Q8WZ42_27572
# 2361
# P12956_46
# 2362
# A0A0G2JWF4_235
# 2363
# Q0JRZ9_678
# 2364
# P24539_18
# 2365
# Q99442_142
# 2366
# P16086_758
# 2367
# O75396_123
# 2368
# Q566C7_18
# 2369
# Q12797_709
# 2370
# P09543_176
# 2371
# G3V8Y8_958
# 2372
# G3V667_744
# 2373
# O60610_844
# 2374
# Q09666_5323
# 2375
# B6RK61_1586
# 2376
# D3ZL10_1372
# 2377
# Q8N9T8_354
# 2378
# O15258_192
# 2379
# Q00688_127
# 2380
# Q13136_756
# 2381
# Q7Z6B0_341
# 2382
# O75369_1645
# 2383
# P27867_142
# 2384
# Q8N5G2_352
# 2385
# D3ZFY8_125
# 2386
# D3ZS74_500
# 2387
# Q13423_323
# 2388
# P46063_44
# 2389
# Q7Z3J3_106
# 2390
# P68255_49
# 2391
# P46087_318
# 2392
# P55265_184
# 2393
# Q9Y2R4_215
# 2394
# Q9NR45_358
# 2395
# Q00796_349
# 2396
# Q09161_188
# 2397
# Q5M8C3_282
# 2398
# Q92598_811
# 2399
# A0A0G2K5T1_288
# 2400
# E9PU28_229
# 2401
# Q9P2R7_148
# 2402
# D4ACS0_758
# 2403
# P05387_41
# 2404
# Q9NWZ3_235
# 2405
# P19784_72
# 2406
# P18583_210
# 2407
# Q5U2Q5_180
# 2408
# A0A0G2KAY8_157
# 2409
# Q9Y2Z0_173
# 2410
# F1LS67_281
# 2411
# G3V6Z7_404
# 2412
# A0A0G2K1F3_699
# 2413
# Q9HD20_220
# 2414
# D4ADD7_198
# 2415
# Q9Z0W5_145
# 2416
# Q9NR30_98
# 2417
# Q9Y6N5_218
# 2418
# A0A0G2JU96_4289
# 2419
# Q5PQK2_308
# 2420
# Q8WWY3_341
# 2421
# A0A0G2JU96_508
# 2422
# P78417_11
# 2423
# P20810_636
# 2424
# P53365_271
# 2425
# O15061_560
# 2426
# Q6ZQQ6_544
# 2427
# Q70UQ0_13
# 2428
# Q03001_2325
# 2429
# Q9Y3B7_115
# 2430
# B1AJZ9_774
# 2431
# Q96I25_167
# 2432
# Q9Y570_273
# 2433
# P49590_147
# 2434
# Q9UHB6_526
# 2435
# Q9Y2X3_494
# 2436
# D3ZL10_1549
# 2437
# Q8IVF2_2984
# 2438
# Q03001_336
# 2439
# A0A0G2JTH6_257
# 2440
# Q5T8P6_670
# 2441
# Q99848_204
# 2442
# P43304_542
# 2443
# Q9GZR2_81
# 2444
# D4A678_281
# 2445
# Q7Z406_1672
# 2446
# F1M8F6_1900
# 2447
# Q9NQ29_224
# 2448
# F1LWK7_260
# 2449
# Q9NSE4_196
# 2450
# Q08J23_516
# 2451
# Q9UHB6_273
# 2452
# F1LRT9_247
# 2453
# O43765_95
# 2454
# Q9NWH9_401
# 2455
# P78312_831
# 2456
# Q14152_1221
# 2457
# F1M6Z1_2848
# 2458
# D3Z8G3_765
# 2459
# Q1ED39_452
# 2460
# A0A0G2JXR0_221
# 2461
# Q8NFC6_1721
# 2462
# G3V9R9_205
# 2463
# F1M949_158
# 2464
# D4A7U1_637
# 2465
# B1WC16_504
# 2466
# A0A0G2JUS4_812
# 2467
# Q99575_683
# 2468
# D4A6A2_86
# 2469
# Q9UIC8_109
# 2470
# D3ZA69_130
# 2471
# Q96ST2_409
# 2472
# Q9P287_241
# 2473
# O95202_125
# 2474
# Q7Z6B0_364
# 2475
# D3ZZ99_143
# 2476
# Q9UPN3_2567
# 2477
# Q86UE4_444
# 2478
# P46977_521
# 2479
# A0A0G2JU89_4506
# 2480
# Q96BP3_626
# 2481
# F1M392_555
# 2482
# D3ZHE5_636
# 2483
# F1LPQ3_183
# 2484
# Q9WVE9_552
# 2485
# Q6NZI2_116
# 2486
# B2RYW9_174
# 2487
# F1LW91_1198
# 2488
# Q6P3V9_163
# 2489
# Q6MZM0_430
# 2490
# O00507_1911
# 2491
# P11940_371
# 2492
# A0A0G2K3W1_1814
# 2493
# A0A0G2JUP3_1810
# 2494
# Q66WT9_348
# 2495
# P16144_1060
# 2496
# D3ZKM9_166
# 2497
# D3ZX42_50
# 2498
# D3ZRX9_93
# 2499
# G3V7J2_177
# 2500
# Q68FW9_153
# 2501
# A0A0U1RRV7_165
# 2502
# P33993_10
# 2503
# D3ZM60_951
# 2504
# Q8NE71_724
# 2505
# Q8WZ42_4668
# 2506
# B0BN63_41
# 2507
# P25705_402
# 2508
# Q66H91_366
# 2509
# A0A0G2K5A4_1248
# 2510
# G3V640_382
# 2511
# Q9NRW1_183
# 2512
# P00558_279
# 2513
# Q9Y3T9_396
# 2514
# D3ZU20_86
# 2515
# Q9ESN0_691
# 2516
# F1M9F6_355
# 2517
# Q8WXH0_737
# 2518
# O75369_593
# 2519
# Q14141_249
# 2520
# B2RYN3_136
# 2521
# Q9UPN4_1041
# 2522
# A0A0G2K6Y4_77
# 2523
# P02770_460
# 2524
# P34932_785
# 2525
# Q9H267_65
# 2526
# O15213_83
# 2527
# P63102_115
# 2528
# Q6QI48_626
# 2529
# Q499S4_547
# 2530
# Q7Z6E9_30
# 2531
# D3ZLP2_1117
# 2532
# Q6S399_601
# 2533
# M3ZCQ2_1552
# 2534
# Q96AX1_580
# 2535
# Q5BK18_138
# 2536
# Q9HC35_119
# 2537
# Q03626_313
# 2538
# D4A1L2_884
# 2539
# Q6DGG0_43
# 2540
# Q568Z6_48
# 2541
# P82995_661
# 2542
# Q8WZ42_33824
# 2543
# P62136_168
# 2544
# A0A0G2K7Q7_121
# 2545
# D4A0U0_278
# 2546
# P46821_658
# 2547
# Q6AYT3_493
# 2548
# Q5QD51_451
# 2549
# A0A0G2K0X9_1018
# 2550
# P17955_261
# 2551
# O08557_196
# 2552
# F1LNH3_564
# 2553
# P47860_759
# 2554
# Q96D46_207
# 2555
# Q5RJQ7_89
# 2556
# P27635_42
# 2557
# D4A3X0_1320
# 2558
# Q8NE71_582
# 2559
# P06685_984
# 2560
# Q70AM4_714
# 2561
# P38656_204
# 2562
# Q923Z2_29
# 2563
# G3V9K0_672
# 2564
# P46413_443
# 2565
# O75116_518
# 2566
# Q99877_29
# 2567
# Q8N9V7_586
# 2568
# A0A0G2JU96_1553
# 2569
# A0A0G2JXI4_486
# 2570
# Q8WZ42_9374
# 2571
# P14923_533
# 2572
# P23246_426
# 2573
# D4A4A9_277
# 2574
# Q9UBB5_167
# 2575
# D3ZPR0_158
# 2576
# Q8WXW3_589
# 2577
# Q12933_119
# 2578
# Q9NTJ3_928
# 2579
# F1M8L1_18
# 2580
# D3ZF39_188
# 2581
# Q86UE4_447
# 2582
# A0A0H2UI19_26
# 2583
# F1LVX2_538
# 2584
# Q06203_406
# 2585
# Q13601_11
# 2586
# D3Z9Z0_426
# 2587
# Q9Y2W2_129
# 2588
# A0A0G2K2G7_109
# 2589
# Q9Y4E1_191
# 2590
# F1LXD8_265
# 2591
# Q9JLA3_378
# 2592
# Q9ULW3_242
# 2593
# Q14562_1053
# 2594
# P46100_2359
# 2595
# P30622_452
# 2596
# D3ZB30_259
# 2597
# Q13618_367
# 2598
# Q09666_3029
# 2599
# D4A2F1_313
# 2600
# Q0ZGT2_461
# 2601
# D3ZJR1_599
# 2602
# Q4KLF8_13
# 2603
# B2GV15_119
# 2604
# P35251_306
# 2605
# Q14562_612
# 2606
# P18858_428
# 2607
# Q00610_1415
# 2608
# P55159_84
# 2609
# E9PSJ4_615
# 2610
# P36876_18
# 2611
# A0A0G2K4T7_745
# 2612
# P04897_210
# 2613
# P49736_816
# 2614
# Q5XIC2_115
# 2615
# P68136_361
# 2616
# D3ZIP3_843
# 2617
# Q02790_98
# 2618
# Q9BUL5_211
# 2619
# P30835_365
# 2620
# Q07009_355
# 2621
# O43707_98
# 2622
# P40121_28
# 2623
# P60900_182
# 2624
# P11532_328
# 2625
# Q8WXH0_664
# 2626
# P35580_968
# 2627
# F1LM66_159
# 2628
# D3ZMS1_412
# 2629
# Q70AM4_442
# 2630
# D3ZLP2_36
# 2631
# O95373_723
# 2632
# D3Z881_1192
# 2633
# D3ZFK6_523
# 2634
# P49915_18
# 2635
# P08754_271
# 2636
# P49327_927
# 2637
# F1LSW7_63
# 2638
# P06214_290
# 2639
# P40227_199
# 2640
# Q92614_21
# 2641
# Q16720_450
# 2642
# Q8WX92_519
# 2643
# Q2M3X9_128
# 2644
# Q14527_355
# 2645
# Q6NVY1_17
# 2646
# P20908_1626
# 2647
# Q3BCU4_182
# 2648
# F1M7X3_581
# 2649
# Q5JTH9_71
# 2650
# P19633_79
# 2651
# F1LSS1_922
# 2652
# F1M124_310
# 2653
# Q14690_471
# 2654
# P18615_25
# 2655
# P27448_303
# 2656
# Q9NZM3_1101
# 2657
# P0C170_119
# 2658
# O00507_1790
# 2659
# D3ZWS0_105
# 2660
# Q5U2Y3_196
# 2661
# Q8N1G4_228
# 2662
# P15529_227
# 2663
# Q92841_284
# 2664
# O15144_290
# 2665
# D3ZIP3_724
# 2666
# Q09666_1865
# 2667
# Q8N3Z0_179
# 2668
# P22314_125
# 2669
# O60287_503
# 2670
# Q8WZ42_16944
# 2671
# P46013_923
# 2672
# Q3MHT2_182
# 2673
# P53804_1902
# 2674
# Q13601_247
# 2675
# G3V7J2_45
# 2676
# P28370_267
# 2677
# P18437_51
# 2678
# Q96JI7_339
# 2679
# A0A0G2K1X6_2637
# 2680
# Q3HSE5_427
# 2681
# Q8WZ42_15420
# 2682
# O43818_113
# 2683
# B0LPN4_991
# 2684
# Q9QZ86_49
# 2685
# D3ZZB0_389
# 2686
# F1M124_186
# 2687
# Q96JI7_1607
# 2688
# P35251_499
# 2689
# Q08945_522
# 2690
# Q86VP6_403
# 2691
# P35221_627
# 2692
# B2GV14_12
# 2693
# Q9Y520_557
# 2694
# D4A2P1_1074
# 2695
# Q02952_309
# 2696
# A0A0G2JYY6_85
# 2697
# D3ZZT9_1599
# 2698
# Q5VYK3_1295
# 2699
# P20908_1167
# 2700
# Q14738_583
# 2701
# A1L130_144
# 2702
# Q00796_175
# 2703
# O60337_808
# 2704
# P33527_908
# 2705
# P46821_1457
# 2706
# F1M0V4_1392
# 2707
# A0A096MKD4_484
# 2708
# A0A0G2K757_214
# 2709
# Q69YQ0_646
# 2710
# H8Y6S5_633
# 2711
# O60832_501
# 2712
# A0A0G2K0X9_811
# 2713
# A0A0G2K751_270
# 2714
# D3ZYT8_508
# 2715
# Q15393_1049
# 2716
# Q8WXH0_2871
# 2717
# Q02790_426
# 2718
# P51659_246
# 2719
# Q96NC0_102
# 2720
# P68433_65
# 2721
# O35867_538
# 2722
# O95881_32
# 2723
# Q7TMA9_336
# 2724
# P46821_1355
# 2725
# P23514_771
# 2726
# P30520_379
# 2727
# A6KI11_83
# 2728
# Q6NX65_68
# 2729
# Q14839_354
# 2730
# Q9BZ67_435
# 2731
# Q4FZT9_219
# 2732
# A0A0G2K542_173
# 2733
# P48637_387
# 2734
# Q8WVV4_127
# 2735
# D3ZGE6_320
# 2736
# A0A0G2K2W6_424
# 2737
# A0A0G2K327_69
# 2738
# D3ZZT9_1048
# 2739
# Q14789_137
# 2740
# Q9ULU4_203
# 2741
# A0A140TAI3_182
# 2742
# Q7Z406_1859
# 2743
# Q99816_33
# 2744
# P11505_737
# 2745
# F1M5V2_169
# 2746
# P55010_55
# 2747
# P20059_237
# 2748
# F1M2P8_105
# 2749
# O94804_621
# 2750
# Q8WZ42_27445
# 2751
# F1M3D3_82
# 2752
# Q63638_2591
# 2753
# F1M6Z1_3626
# 2754
# A0A0H2UHB3_83
# 2755
# Q03001_1240
# 2756
# D3ZCI6_414
# 2757
# Q9UBX8_317
# 2758
# Q7KZ85_623
# 2759
# Q13813_1500
# 2760
# P07954_467
# 2761
# Q8N9R6_135
# 2762
# Q9BVL2_536
# 2763
# Q8WWL2_608
# 2764
# Q8TE73_3371
# 2765
# D3ZC56_7079
# 2766
# Q3ZB99_494
# 2767
# P07339_49
# 2768
# P60228_227
# 2769
# A0A0G2QC21_230
# 2770
# A0A0G2JXB1_159
# 2771
# D4A2P1_1019
# 2772
# D4AA54_5
# 2773
# P26358_284
# 2774
# Q13618_743
# 2775
# F1LRI5_475
# 2776
# Q64244_144
# 2777
# P51003_407
# 2778
# Q5HZE4_44
# 2779
# E9PT65_263
# 2780
# P11766_7
# 2781
# O15118_142
# 2782
# F1MAB9_186
# 2783
# Q8N766_594
# 2784
# Q5CZC0_5143
# 2785
# Q8WZ42_16860
# 2786
# P27694_343
# 2787
# F1M4I1_142
# 2788
# M0RBJ7_465
# 2789
# B0LPN4_2609
# 2790
# A0A0G2JVW5_1598
# 2791
# P15205_1348
# 2792
# P24473_62
# 2793
# P0C1X8_337
# 2794
# Q66HG4_145
# 2795
# Q8WUM4_110
# 2796
# Q5CZC0_5031
# 2797
# O43143_608
# 2798
# D4AEL8_325
# 2799
# D4A318_962
# 2800
# Q14651_457
# 2801
# Q5T1M5_716
# 2802
# P05362_273
# 2803
# P11177_173
# 2804
# O95104_586
# 2805
# Q63570_125
# 2806
# D3ZC56_668
# 2807
# F1M4Q1_26
# 2808
# Q5RK17_103
# 2809
# P61326_114
# 2810
# Q9BW91_194
# 2811
# Q14789_2432
# 2812
# G3V6G7_345
# 2813
# Q9UPN3_7268
# 2814
# F1LMV2_124
# 2815
# A0A0G2JTW5_310
# 2816
# Q62780_363
# 2817
# Q5XI26_480
# 2818
# A0A0G2K059_218
# 2819
# P35659_315
# 2820
# D3ZM60_840
# 2821
# Q14789_1858
# 2822
# D3ZWS0_266
# 2823
# P39748_125
# 2824
# Q96GQ7_661
# 2825
# G3V662_1459
# 2826
# Q9BZE4_111
# 2827
# O75396_43
# 2828
# O95425_2151
# 2829
# Q6P4E1_375
# 2830
# P48651_179
# 2831
# Q9UPN3_1731
# 2832
# Q01970_219
# 2833
# Q9NVA2_418
# 2834
# D4ABI6_77
# 2835
# O43252_459
# 2836
# Q96AX1_313
# 2837
# O43395_495
# 2838
# Q9Y639_235
# 2839
# Q05519_436
# 2840
# O43660_271
# 2841
# G3V9N7_154
# 2842
# D3ZBM3_392
# 2843
# P19234_124
# 2844
# Q96IZ0_270
# 2845
# Q9Y520_183
# 2846
# Q6IRK8_1787
# 2847
# Q9UKK3_572
# 2848
# O95757_671
# 2849
# Q5I0H9_102
# 2850
# Q9Z1H9_208
# 2851
# P33778_86
# 2852
# A0A0G2JSP3_585
# 2853
# Q13601_73
# 2854
# Q9BUJ2_270
# 2855
# A9UMW0_41
# 2856
# F1LPG9_646
# 2857
# Q99798_717
# 2858
# Q5XI17_121
# 2859
# Q8NE71_263
# 2860
# Q9UM54_945
# 2861
# P55084_44
# 2862
# Q9NQC3_328
# 2863
# P43278_175
# 2864
# O14617_55
# 2865
# A6IA08_534
# 2866
# P51572_214
# 2867
# P11530_535
# 2868
# P22314_802
# 2869
# D3ZCI6_605
# 2870
# Q16719_163
# 2871
# P61254_132
# 2872
# G3V7V6_336
# 2873
# A0A0G2K4T7_266
# 2874
# M0RC54_1341
# 2875
# P61964_159
# 2876
# A0A0G2JW88_2061
# 2877
# Q5U3Z7_302
# 2878
# O43264_44
# 2879
# Q6P6R2_215
# 2880
# Q9NQV7_606
# 2881
# Q96AE4_76
# 2882
# D4A772_317
# 2883
# Q8IWJ2_509
# 2884
# Q709F0_387
# 2885
# O00370_1063
# 2886
# B1A2U8_608
# 2887
# P25788_192
# 2888
# A0A0G2JZZ7_556
# 2889
# G3V6H2_595
# 2890
# Q63486_236
# 2891
# Q6P1A2_283
# 2892
# P48307_217
# 2893
# Q9GZU8_121
# 2894
# Q8N9I0_367
# 2895
# P62829_75
# 2896
# Q8NFC6_2069
# 2897
# A0A1B0GWM7_396
# 2898
# A0A0G2K5A4_197
# 2899
# Q1JU68_563
# 2900
# Q63HN8_1777
# 2901
# A0A0G2JYT1_718
# 2902
# Q9Y653_518
# 2903
# Q6AY99_155
# 2904
# P28288_289
# 2905
# Q13769_153
# 2906
# Q14126_919
# 2907
# A0A0G2K7W4_630
# 2908
# Q5GLZ8_959
# 2909
# D3ZAY8_298
# 2910
# Q9Y4I1_1528
# 2911
# Q09666_3760
# 2912
# A2RRP1_132
# 2913
# Q8WZ42_20475
# 2914
# P78527_1970
# 2915
# P49327_326
# 2916
# P49242_219
# 2917
# P17844_437
# 2918
# Q15904_168
# 2919
# Q9UBE0_217
# 2920
# P17174_56
# 2921
# A0A0G2JW70_34
# 2922
# Q8WWI1_335
# 2923
# Q9Y6E2_309
# 2924
# F1LUA1_250
# 2925
# Q96M83_453
# 2926
# P11532_1568
# 2927
# Q9Z1E1_211
# 2928
# Q6I9Y2_186
# 2929
# Q9UN76_307
# 2930
# G3V7Q7_1439
# 2931
# Q8N4X5_691
# 2932
# Q499S4_316
# 2933
# M0RAI4_151
# 2934
# A0A0G2K2M9_999
# 2935
# Q96K83_983
# 2936
# O35867_500
# 2937
# A0A0G2JTN3_626
# 2938
# A0A0G2K781_309
# 2939
# Q8WWQ0_6
# 2940
# Q9NTI5_380
# 2941
# A0A0G2JYB1_168
# 2942
# Q08290_74
# 2943
# Q9NQW6_647
# 2944
# A0A0G2KAM3_406
# 2945
# Q5BJU0_197
# 2946
# P16401_37
# 2947
# G3V624_462
# 2948
# P55072_62
# 2949
# Q8NEJ9_190
# 2950
# Q7TP52_218
# 2951
# Q8WX93_403
# 2952
# O60271_769
# 2953
# F1LRT9_4366
# 2954
# P05197_400
# 2955
# Q92621_1865
# 2956
# P49588_172
# 2957
# A0A0H2UHV4_1124
# 2958
# A0A0G2K850_386
# 2959
# Q5FVN2_87
# 2960
# Q14980_73
# 2961
# Q96ST3_937
# 2962
# B2RYL2_347
# 2963
# Q9ES53_42
# 2964
# O95232_281
# 2965
# Q15459_97
# 2966
# A0A0G2K6R8_853
# 2967
# Q8WXH0_1363
# 2968
# A0A0G2K3C8_1364
# 2969
# P36873_301
# 2970
# Q99996_1941
# 2971
# Q99996_2985
# 2972
# M0R660_115
# 2973
# G3V9N0_277
# 2974
# P53396_1017
# 2975
# Q99996_2255
# 2976
# F1LM33_1171
# 2977
# Q14008_55
# 2978
# G3V7K1_974
# 2979
# P20700_474
# 2980
# Q9H0D6_286
# 2981
# Q9UJX2_379
# 2982
# Q9Y6A5_720
# 2983
# A0A0G2K5C7_322
# 2984
# B2RYB3_83
# 2985
# P08133_314
# 2986
# A0A0G2JY08_644
# 2987
# Q96AC1_622
# 2988
# F1LMC2_680
# 2989
# P15791_299
# 2990
# O15260_115
# 2991
# Q09666_4342
# 2992
# D3ZFH5_758
# 2993
# Q14692_1177
# ...
# 23005
# Q16658_431
# 23006
# A0A0G2JX64_70
# 23007
# D4AEH9_1407
# 23008
# Q711G3_143
# 23009
# P26038_448
# 23010
# P78347_570
# 23011
# Q15061_596
# 23012
# P10412_117
# 23013
# Q2PZI1_608
# 23014
# Q9NS86_164
# 23015
# Q02218_561
# 23016
# Q03001_4385
# 23017
# P25205_558
# 23018
# D3ZCL3_40
# 23019
# Q9UQ80_370
# 23020
# P12235_206
# 23021
# Q09666_2194
# 23022
# A0A0G2JXI4_673
# 23023
# Q9NUI1_230
# 23024
# A6JEK1_318
# 23025
# Q8WVV4_304
# 23026
# F1M8K0_248
# 23027
# G3V7T3_590
# 23028
# Q96A65_795
# 23029
# F1M0V4_943
# 23030
# Q07955_193
# 23031
# Q13813_2017
# 23032
# O00370_280
# 23033
# A0A0G2JVW5_2615
# 23034
# D4A2D8_32
# 23035
# Q6AY02_15
# 23036
# P26284_186
# 23037
# D4A3K5_17
# 23038
# A0A0G2JYF7_228
# 23039
# P51146_122
# 23040
# P23229_909
# 23041
# Q8NDV3_294
# 23042
# Q53EU6_221
# 23043
# D3ZBS2_308
# 23044
# F1LM42_3446
# 23045
# Q6WKZ4_803
# 23046
# Q6IN39_330
# 23047
# B4F7D1_87
# 23048
# Q64240_136
# 23049
# P46940_1353
# 23050
# P61765_343
# 23051
# A0A0G2K6H2_39
# 23052
# O94851_56
# 23053
# F1M484_548
# 23054
# Q9UBL3_393
# 23055
# P81795_90
# 23056
# O75150_743
# 23057
# F1MA36_127
# 23058
# Q14692_190
# 23059
# Q8N4X5_791
# 23060
# F1LRI5_259
# 23061
# Q16666_507
# 23062
# P60228_73
# 23063
# Q9NVJ2_182
# 23064
# F1LNF7_381
# 23065
# Q12965_118
# 23066
# Q6PDW1_102
# 23067
# A0A0G2JSH5_184
# 23068
# Q7Z406_962
# 23069
# A0A0G2JTB2_51
# 23070
# Q9UPN3_4448
# 23071
# F1M853_561
# 23072
# A0A0A0MXW1_165
# 23073
# A0A0G2K5L6_901
# 23074
# P46063_353
# 23075
# G3V9M6_2539
# 23076
# P08237_649
# 23077
# Q9Y5X3_358
# 23078
# P52925_12
# 23079
# B5DEY8_180
# 23080
# Q8IX12_687
# 23081
# D3ZM69_717
# 23082
# O14646_1463
# 23083
# Q8WXW3_661
# 23084
# P46379_80
# 23085
# Q12797_588
# 23086
# Q8IVF2_2144
# 23087
# A0A0G2JWM2_193
# 23088
# Q5RJR8_7
# 23089
# Q8TE59_1069
# 23090
# Q9UPN3_2541
# 23091
# M0R7S5_816
# 23092
# P46013_2826
# 23093
# O95232_315
# 23094
# Q15008_346
# 23095
# D3ZUF9_860
# 23096
# D3ZUZ9_162
# 23097
# D3ZZZ9_367
# 23098
# P11388_227
# 23099
# Q6URK4_108
# 23100
# Q9Y6A5_562
# 23101
# Q6ZR08_2879
# 23102
# Q08J23_46
# 23103
# G3V918_807
# 23104
# O00507_1994
# 23105
# D4A7R0_461
# 23106
# Q9Y4I1_1227
# 23107
# P61247_15
# 23108
# Q9EQP5_32
# 23109
# Q13085_1667
# 23110
# P33121_697
# 23111
# P67936_113
# 23112
# D4A997_231
# 23113
# F1M609_182
# 23114
# Q15008_349
# 23115
# Q13206_245
# 23116
# Q9P258_470
# 23117
# A0A140UHX6_641
# 23118
# Q04446_488
# 23119
# P48426_368
# 23120
# Q4V7C7_228
# 23121
# D3ZQT0_165
# 23122
# Q8N3Z0_228
# 23123
# D4AAY3_730
# 23124
# F1LRT9_2018
# 23125
# G3V7Q7_556
# 23126
# Q811X6_102
# 23127
# P62701_254
# 23128
# G3V7I8_1164
# 23129
# P61254_113
# 23130
# P27008_353
# 23131
# A0A0G2JYM6_266
# 23132
# Q03001_38
# 23133
# P09429_141
# 23134
# F1LSM5_9
# 23135
# D3ZLP2_844
# 23136
# M0RAK2_46
# 23137
# Q9Y490_1654
# 23138
# F1LPQ3_466
# 23139
# D3ZLJ9_15
# 23140
# A0A0H2UHR7_1531
# 23141
# Q99996_1446
# 23142
# P30048_73
# 23143
# O14980_560
# 23144
# D4AAR7_1080
# 23145
# D4A1B9_610
# 23146
# Q08211_1037
# 23147
# D4A8G5_60
# 23148
# D3Z9Z0_54
# 23149
# Q9Y6M7_946
# 23150
# Q66H94_388
# 23151
# A0A0G2K484_1525
# 23152
# P09874_236
# 23153
# Q13439_64
# 23154
# Q6P4E1_149
# 23155
# Q8IXB1_79
# 23156
# B4F763_331
# 23157
# Q13740_60
# 23158
# Q93079_16
# 23159
# P15205_696
# 23160
# Q63HN8_3404
# 23161
# A0A0G2JVW6_1184
# 23162
# A0A096MJS3_701
# 23163
# O88656_289
# 23164
# D3ZPV8_50
# 23165
# O94804_606
# 23166
# G3V7L1_3240
# 23167
# B4EUF7_126
# 23168
# Q66HL2_171
# 23169
# F1LQI1_170
# 23170
# P49756_697
# 23171
# F1LPK7_501
# 23172
# Q8WZ42_31015
# 23173
# Q9UNE7_287
# 23174
# Q14690_418
# 23175
# A0A0G2K4T8_456
# 23176
# Q12849_382
# 23177
# P97536_729
# 23178
# Q13200_632
# 23179
# G3V9R9_452
# 23180
# F1LMC2_2376
# 23181
# O95453_607
# 23182
# A0A096MJS3_232
# 23183
# P05141_295
# 23184
# Q9UHN6_278
# 23185
# Q99460_825
# 23186
# Q71LX6_1022
# 23187
# Q96I99_118
# 23188
# P46940_477
# 23189
# Q9UKL0_231
# 23190
# Q9UIG0_101
# 23191
# A0A0G2JYT1_787
# 23192
# A0A3B6QEZ5_366
# 23193
# F1LMC6_175
# 23194
# D3ZTK5_72
# 23195
# P49790_736
# 23196
# P48637_245
# 23197
# D4A3T3_102
# 23198
# T2CB11_396
# 23199
# Q12840_357
# 23200
# Q9H078_207
# 23201
# Q96C01_113
# 23202
# Q99798_233
# 23203
# P11766_373
# 23204
# Q8WZA0_11
# 23205
# Q9ERB4_1973
# 23206
# Q9H1A4_739
# 23207
# Q6ZT07_1076
# 23208
# A0A0G2JUC7_338
# 23209
# P50411_145
# 23210
# M0RC54_994
# 23211
# B0BN18_62
# 23212
# Q13464_709
# 23213
# G3V8B0_106
# 23214
# P27708_424
# 23215
# Q86UP2_1167
# 23216
# M0RA24_37
# 23217
# F7EUU4_354
# 23218
# P39023_399
# 23219
# Q14566_599
# 23220
# P08082_210
# 23221
# A0A0G2JU89_3627
# 23222
# Q68FS8_156
# 23223
# Q9Y2X3_20
# 23224
# G3V9E4_416
# 23225
# G3V885_1816
# 23226
# Q6PD62_959
# 23227
# P21589_145
# 23228
# Q9H0D6_641
# 23229
# Q8TDD1_874
# 23230
# Q53EU6_59
# 23231
# Q03001_5299
# 23232
# Q00610_140
# 23233
# P02564_1392
# 23234
# D4A1B9_460
# 23235
# D4ABK7_21
# 23236
# A0A0G2K8Y7_246
# 23237
# P13674_274
# 23238
# O95425_1493
# 23239
# P13264_369
# 23240
# Q15393_328
# 23241
# A0A0G2JZH0_7
# 23242
# Q7L2E3_303
# 23243
# Q8TDW0_620
# 23244
# Q9BRF8_230
# 23245
# Q9ULB4_371
# 23246
# B5DEZ4_478
# 23247
# G3V7I3_214
# 23248
# P23634_1144
# 23249
# P54921_246
# 23250
# A0A0G2JU89_3638
# 23251
# P46413_400
# 23252
# P26373_42
# 23253
# Q8WXH0_4653
# 23254
# Q6IN39_684
# 23255
# Q01970_979
# 23256
# Q8IVF2_4218
# 23257
# F1LSM5_614
# 23258
# O60869_135
# 23259
# Q5JRX3_125
# 23260
# D3ZN12_605
# 23261
# O43615_209
# 23262
# P12955_118
# 23263
# G3V7T6_874
# 23264
# Q9UKF6_545
# 23265
# A0A0G2K350_123
# 23266
# F1LNS0_1189
# 23267
# Q6IE52_1367
# 23268
# Q9BYX2_103
# 23269
# P49756_355
# 23270
# P52209_460
# 23271
# O94925_320
# 23272
# P22102_508
# 23273
# P11586_504
# 23274
# Q8WZ42_25483
# 23275
# Q6P502_528
# 23276
# O60229_1379
# 23277
# P33121_263
# 23278
# Q92805_510
# 23279
# Q63HN8_472
# 23280
# Q01082_976
# 23281
# P49792_1466
# 23282
# Q7KZ85_748
# 23283
# F1MAA7_1074
# 23284
# P46013_587
# 23285
# M0R410_795
# 23286
# Q9NVP1_370
# 23287
# Q99996_2538
# 23288
# F1M049_1080
# 23289
# Q8N9T8_555
# 23290
# O75116_238
# 23291
# A6KRS3_2157
# 23292
# Q13435_563
# 23293
# O43719_113
# 23294
# Q8WWY3_58
# 23295
# A0A0G2JXT0_30
# 23296
# F1M9Y8_1651
# 23297
# B2RYD7_237
# 23298
# Q9Y5K6_105
# 23299
# A0A0H2UHQ9_501
# 23300
# D3ZYR1_262
# 23301
# A0A0G2JU96_3828
# 23302
# P15205_972
# 23303
# Q92973_646
# 23304
# F1M3H8_96
# 23305
# F1LN92_140
# 23306
# P49915_325
# 23307
# M9MMM9_5342
# 23308
# P42167_144
# 23309
# D3ZDX7_71
# 23310
# G3V7I3_1125
# 23311
# Q9QVC8_98
# 23312
# Q01970_27
# 23313
# P03957_315
# 23314
# Q8IUD2_894
# 23315
# Q9NRW1_13
# 23316
# A0A0G2K047_151
# 23317
# P28370_862
# 23318
# Q14444_110
# 23319
# P30838_449
# 23320
# F1LSS1_311
# 23321
# B1WBY1_71
# 23322
# Q15629_342
# 23323
# G3V7I8_266
# 23324
# P43243_611
# 23325
# Q15155_791
# 23326
# P07814_1494
# 23327
# O94808_319
# 23328
# Q6DRA6_29
# 23329
# O08749_66
# 23330
# Q13263_575
# 23331
# A6J6W0_177
# 23332
# Q09073_23
# 23333
# Q9WVE9_1463
# 23334
# P08243_556
# 23335
# M0R9L0_729
# 23336
# F1M7Y3_228
# 23337
# Q6AYS7_244
# 23338
# D4A4Z9_561
# 23339
# Z4YNF4_7
# 23340
# Q8N1G4_563
# 23341
# A0A0G2K0F5_273
# 23342
# Q561S0_268
# 23343
# Q6P9U8_241
# 23344
# D3ZFJ6_153
# 23345
# P50399_390
# 23346
# P15205_1019
# 23347
# Q8K1Q0_414
# 23348
# P10599_36
# 23349
# P04908_126
# 23350
# B2RYB3_249
# 23351
# P55053_112
# 23352
# P70541_437
# 23353
# A0A0G2K327_207
# 23354
# Q8NHQ9_533
# 23355
# G3V7E6_1297
# 23356
# P46940_1657
# 23357
# A0A0G2K911_148
# 23358
# Q9GZR7_429
# 23359
# B2RZ74_167
# 23360
# O95373_201
# 23361
# Q99590_1126
# 23362
# Q96JI7_2413
# 23363
# D3ZQL7_188
# 23364
# Q6AY09_167
# 23365
# Q99459_70
# 23366
# Q13523_76
# 23367
# F1M3G7_516
# 23368
# A0A0H2UHI2_70
# 23369
# Q5HZA7_20
# 23370
# P15144_497
# 23371
# Q96JI7_777
# 23372
# Q14573_69
# 23373
# P49257_303
# 23374
# A0A1W2Q628_2945
# 23375
# P49736_331
# 23376
# B0BNM1_91
# 23377
# Q63570_330
# 23378
# Q03001_3109
# 23379
# A0A140TAE0_711
# 23380
# F1LPV0_392
# 23381
# F1LMK0_399
# 23382
# B5DEZ4_434
# 23383
# Q9P2D0_821
# 23384
# Q63607_259
# 23385
# E9PST5_550
# 23386
# A0A0G2JWF4_75
# 23387
# A0A0G2K9H3_517
# 23388
# Q8IWJ2_264
# 23389
# Q9Z0V5_85
# 23390
# Q9NQ50_59
# 23391
# P27816_784
# 23392
# G3V6A8_517
# 23393
# Q9BRF8_81
# 23394
# Q5JSH3_314
# 23395
# Q96T51_390
# 23396
# P20810_426
# 23397
# D4ACS0_487
# 23398
# Q02543_21
# 23399
# Q14204_1655
# 23400
# A6IPG1_186
# 23401
# Q62824_487
# 23402
# P61765_577
# 23403
# Q5RJR8_189
# 23404
# D3ZZB0_34
# 23405
# Q13895_277
# 23406
# O88377_165
# 23407
# Q99460_324
# 23408
# P55160_591
# 23409
# Q9NX40_217
# 23410
# Q9H0S4_422
# 23411
# E9PTJ1_137
# 23412
# Q96M83_484
# 23413
# A6KQL1_94
# 23414
# B2RYD7_524
# 23415
# Q5U312_48
# 23416
# Q8IVF2_3909
# 23417
# P27008_197
# 23418
# A0A0G2JW97_58
# 23419
# P36551_404
# 23420
# Q5XIG8_69
# 23421
# Q9NWH9_546
# 23422
# F1LVF9_78
# 23423
# Q5U2Q5_236
# 23424
# O15042_392
# 23425
# Q14108_181
# 23426
# P05197_676
# 23427
# Q8WVM8_356
# 23428
# O00507_758
# 23429
# Q969G3_68
# 23430
# Q10567_490
# 23431
# F1M4M7_650
# 23432
# Q9H4M9_162
# 23433
# O43837_96
# 23434
# O14617_749
# 23435
# P46087_767
# 23436
# O60841_268
# 23437
# P02770_604
# 23438
# P04114_1280
# 23439
# P08238_273
# 23440
# P04040_23
# 23441
# Q9NX58_251
# 23442
# F1LSS1_308
# 23443
# A0A0G2JU89_2203
# 23444
# D3ZZ68_493
# 23445
# D3ZCL8_788
# 23446
# Q9BWW8_136
# 23447
# O00429_718
# 23448
# Q6ZR08_1464
# 23449
# A0A0G2JZI2_720
# 23450
# Q7Z3D4_113
# 23451
# P16989_311
# 23452
# Q58FF8_53
# 23453
# Q02878_12
# 23454
# Q15012_224
# 23455
# O60488_223
# 23456
# D4A4J0_92
# 23457
# F1MAH8_686
# 23458
# Q9C0C9_1164
# 23459
# Q6ZR08_417
# 23460
# Q9Y4D1_1019
# 23461
# Q9NWX6_112
# 23462
# Q99996_3116
# 23463
# A0A0G2K5C7_683
# 23464
# Q63530_163
# 23465
# P00480_289
# 23466
# Q63HN8_11
# 23467
# A0A0H2UHK5_551
# 23468
# Q70AM4_815
# 23469
# A0A0G2K3V4_1032
# 23470
# Q9Z0W5_186
# 23471
# F1M9Y8_916
# 23472
# F1M6Z1_402
# 23473
# Q96AX1_272
# 23474
# O15213_503
# 23475
# Q9NQG5_275
# 23476
# O94842_281
# 23477
# P43277_82
# 23478
# Q13285_94
# 23479
# D3ZC56_4593
# 23480
# D3ZLP2_339
# 23481
# Q86UP2_272
# 23482
# Q9Y5X3_118
# 23483
# P07942_1164
# 23484
# Q16739_164
# 23485
# Q641Y8_535
# 23486
# Q8WXH0_2001
# 23487
# E9PT53_144
# 23488
# Q14203_1247
# 23489
# A0A0G2K3W1_633
# 23490
# P16144_191
# 23491
# Q15418_537
# 23492
# M0RC54_1059
# 23493
# D4A6X1_269
# 23494
# Q6P7B0_375
# 23495
# B2GV74_145
# 23496
# A0A0G2K6B7_665
# 23497
# P60953_27
# 23498
# F1M6Z1_1325
# 23499
# P61201_77
# 23500
# Q8IXB1_222
# 23501
# F1M4Q1_436
# 23502
# A0A0G2JU89_767
# 23503
# O75157_672
# 23504
# G3V6S2_454
# 23505
# Q4V8B7_197
# 23506
# O95758_257
# 23507
# P14480_227
# 23508
# Q14151_53
# 23509
# Q92667_634
# 23510
# Q12802_1771
# 23511
# O00203_156
# 23512
# Q6S399_2590
# 23513
# A0A0G2JZF0_918
# 23514
# A6J7I2_254
# 23515
# B2RYN0_487
# 23516
# Q8NDV3_38
# 23517
# F8WFR6_95
# 23518
# O60610_847
# 23519
# G3V8B0_918
# 23520
# O75400_461
# 23521
# Q8WVM8_396
# 23522
# F1LRS8_470
# 23523
# O60271_1177
# 23524
# O14730_318
# 23525
# Q9Y2L1_331
# 23526
# Q7KZF4_409
# 23527
# F1LMV6_950
# 23528
# A0A0G2K5T1_1050
# 23529
# Q16537_439
# 23530
# Q5JRA6_344
# 23531
# P52925_173
# 23532
# Q8NFI4_360
# 23533
# P41542_51
# 23534
# Q5HZA9_184
# 23535
# Q8WZ42_11520
# 23536
# P02563_611
# 23537
# Q8WZ42_25430
# 23538
# M0R9L3_426
# 23539
# A0A0G2K4T7_571
# 23540
# Q9Y2W1_470
# 23541
# P46734_20
# 23542
# A0A0G2JUP3_1111
# 23543
# Q13277_263
# 23544
# P17987_153
# 23545
# Q5JTH9_771
# 23546
# Q80ZA3_48
# 23547
# G3V9T7_129
# 23548
# Q9BXF6_303
# 23549
# D4A8H8_879
# 23550
# Q7Z6B0_308
# 23551
# Q9Y265_7
# 23552
# P31689_350
# 23553
# P43304_190
# 23554
# P21531_143
# 23555
# D3ZEY0_96
# 23556
# Q9H583_389
# 23557
# Q9BZ67_356
# 23558
# P61158_340
# 23559
# P60866_51
# 23560
# A0A0G2JSI1_263
# 23561
# A0A0G2JU83_512
# 23562
# P30533_287
# 23563
# A0A0G2JU96_3999
# 23564
# D4A6A2_105
# 23565
# Q96KC8_401
# 23566
# P02563_1642
# 23567
# O95425_247
# 23568
# Q9ULU4_1157
# 23569
# D3ZWC6_505
# 23570
# P49792_1625
# 23571
# Q62780_605
# 23572
# P27708_395
# 23573
# Q920J3_66
# 23574
# P18163_557
# 23575
# F1M6Z1_2318
# 23576
# P11940_104
# 23577
# O00507_416
# 23578
# P35579_1352
# 23579
# G3V628_162
# 23580
# Q8WZ42_9587
# 23581
# F1LRT9_108
# 23582
# G3V7T6_163
# 23583
# P54577_297
# 23584
# F1LRT9_4152
# 23585
# A0A0G2K9C8_714
# 23586
# O60291_374
# 23587
# D3ZC56_4033
# 23588
# F1LUV9_386
# 23589
# P42285_792
# 23590
# M9MMM9_409
# 23591
# P53618_786
# 23592
# A0A096MIX6_85
# 23593
# P31977_516
# 23594
# B1WC34_300
# 23595
# F1LM42_73
# 23596
# Q14839_219
# 23597
# O15118_831
# 23598
# A0A0G2K542_77
# 23599
# Q14690_1462
# 23600
# Q6V9V9_210
# 23601
# F1LUA1_1012
# 23602
# Q9C0B1_121
# 23603
# P30740_143
# 23604
# O43491_99
# 23605
# P62919_145
# 23606
# Q5U306_337
# 23607
# Q04637_643
# 23608
# Q03001_6121
# 23609
# Q12874_273
# 23610
# Q14671_1143
# 23611
# Q63HN8_4995
# 23612
# D4A997_522
# 23613
# D4A4T9_82
# 23614
# Q1KMD3_593
# 23615
# Q1JU68_901
# 23616
# D3ZBS2_159
# 23617
# Q9H0A0_479
# 23618
# Q5M775_51
# 23619
# P49721_41
# 23620
# F1LNC3_490
# 23621
# Q8TEQ6_817
# 23622
# G3V9Z6_331
# 23623
# Q6TUH0_415
# 23624
# P04639_111
# 23625
# P21743_221
# 23626
# D4A617_315
# 23627
# Q7TMA9_308
# 23628
# Q92665_284
# 23629
# F1LMC2_1406
# 23630
# Q96I25_139
# 23631
# Q06210_154
# 23632
# O00370_924
# 23633
# Q13439_529
# 23634
# Q9NQZ2_473
# 23635
# Q62865_508
# 23636
# O43290_719
# 23637
# Q5QD51_520
# 23638
# Q96D46_454
# 23639
# Q15075_892
# 23640
# A0A0G2JSW3_77
# 23641
# Q13625_322
# 23642
# Q92922_615
# 23643
# D3ZZT9_83
# 23644
# Q5XIH4_369
# 23645
# Q8TE73_2284
# 23646
# A0A0G2K104_450
# 23647
# D4ACK1_1879
# 23648
# D3ZHV1_429
# 23649
# Q9NVM9_167
# 23650
# F1LMV6_988
# 23651
# P38606_467
# 23652
# Q9JJ31_356
# 23653
# Q6DD88_539
# 23654
# O60841_1016
# 23655
# P55060_217
# 23656
# A0A0H2UHV4_223
# 23657
# Q9UQE7_310
# 23658
# P22307_132
# 23659
# A0A0G2K2W6_2530
# 23660
# Q68FT7_176
# 23661
# B3DMA1_346
# 23662
# O95104_235
# 23663
# Q8WZ42_17189
# 23664
# O15042_962
# 23665
# Q9Y3A5_195
# 23666
# Q6XLI7_952
# 23667
# Q13439_674
# 23668
# Q3KRD5_215
# 23669
# Q09MP3_834
# 23670
# Q53T59_325
# 23671
# A0A0G2JUP3_4206
# 23672
# A0A0H2UI21_92
# 23673
# D3ZAY8_202
# 23674
# O95347_422
# 23675
# G3V778_284
# 23676
# P53804_830
# 23677
# P17676_287
# 23678
# Q9NYL2_538
# 23679
# A0A0G2JVG4_140
# 23680
# D3ZCQ9_137
# 23681
# G3V7E6_1596
# 23682
# O15061_450
# 23683
# O75179_2239
# 23684
# O95163_815
# 23685
# A0A0G2K401_402
# 23686
# O14776_472
# 23687
# Q15067_128
# 23688
# P15907_358
# 23689
# F1LP30_368
# 23690
# F1LX28_116
# 23691
# F1LRT9_335
# 23692
# Q8NDV3_285
# 23693
# A0A0G2JTW5_146
# 23694
# F2Z3T9_116
# 23695
# A0A0H2UI10_768
# 23696
# A0A096MKD4_66
# 23697
# O14578_1094
# 23698
# A0A0G2JSK5_414
# 23699
# P10412_159
# 23700
# B1H2A6_408
# 23701
# B2RYS8_53
# 23702
# Q9UIQ6_869
# 23703
# D3ZC56_4313
# 23704
# O75663_102
# 23705
# Q8WZ42_10765
# 23706
# P46100_1871
# 23707
# D4A365_651
# 23708
# Q14671_1060
# 23709
# Q13948_390
# 23710
# Q15746_1197
# 23711
# Q16537_20
# 23712
# Q9UH65_535
# 23713
# Q96TA2_611
# 23714
# Q07666_96
# 23715
# Q5GLZ8_237
# 23716
# P16435_56
# 23717
# Q9Y6E2_18
# 23718
# O00267_414
# 23719
# P24155_303
# 23720
# P43424_50
# 23721
# A0A0G2K351_86
# 23722
# Q9BZH6_94
# 23723
# F1LS86_103
# 23724
# G3V9Y1_106
# 23725
# P61981_28
# 23726
# O35889_362
# 23727
# D4A0B4_710
# 23728
# P42345_1511
# 23729
# F6Q5K7_149
# 23730
# Q7Z6E9_1097
# 23731
# Q9GZR7_608
# 23732
# A0A0H2UH99_112
# 23733
# D3ZUF9_889
# 23734
# Q9Y6D9_504
# 23735
# E9PT87_519
# 23736
# M0RCH6_114
# 23737
# Q13464_1208
# 23738
# P48634_1677
# 23739
# O75153_903
# 23740
# Q7KZ85_452
# 23741
# M0R7S5_178
# 23742
# Q96B97_267
# 23743
# P23457_209
# 23744
# O14880_37
# 23745
# Q99PV2_11
# 23746
# Q9R085_758
# 23747
# P35565_128
# 23748
# Q92973_44
# 23749
# A0A0G2JU96_778
# 23750
# A0A0A0MXZ0_42
# 23751
# Q66H39_95
# 23752
# O14657_75
# 23753
# O43159_413
# 23754
# D3ZI99_361
# 23755
# Q8WZ42_19361
# 23756
# B0BN81_42
# 23757
# D3ZQ57_1272
# 23758
# O60563_247
# 23759
# Q63450_49
# 23760
# A0A0G2K6U1_150
# 23761
# P16086_1939
# 23762
# O00159_704
# 23763
# Q4G061_307
# 23764
# P54577_47
# 23765
# X1WI37_224
# 23766
# A0A0G2JVK4_205
# 23767
# Q00610_993
# 23768
# D4A3S8_425
# 23769
# Q99805_328
# 23770
# Q9Y224_72
# 23771
# Q4FZT0_178
# 23772
# Q9Y618_1594
# 23773
# P0CC10_259
# 23774
# D4A9N5_291
# 23775
# P48634_954
# 23776
# Q04725_220
# 23777
# Q8R3Z7_512
# 23778
# Q56R20_495
# 23779
# O35142_219
# 23780
# D4AEL8_56
# 23781
# F1LMC2_411
# 23782
# F1LUV9_801
# 23783
# A0A0G2K1K6_158
# 23784
# D3ZC56_7281
# 23785
# P21796_256
# 23786
# A0A0G2K2T6_48
# 23787
# O35142_669
# 23788
# O75477_228
# 23789
# G3V6S3_252
# 23790
# A0A140UHW9_1216
# 23791
# Q9BQ39_399
# 23792
# Q2Y0W8_936
# 23793
# F7EUU4_180
# 23794
# Q92667_800
# 23795
# F1MAA3_498
# 23796
# A6INQ7_374
# 23797
# A0A0G2JU95_183
# 23798
# Q8WU90_120
# 23799
# P07602_414
# 23800
# F1LRS8_378
# 23801
# P13233_196
# 23802
# O75534_217
# 23803
# Q96B97_269
# 23804
# P61221_385
# 23805
# D4A3K5_144
# 23806
# P55160_906
# 23807
# F7FLB2_366
# 23808
# Q03001_7199
# 23809
# F1LRT9_1928
# 23810
# P27824_553
# 23811
# A0A0G2JSP3_378
# 23812
# P08758_301
# 23813
# P35268_10
# 23814
# D4A022_1390
# 23815
# P12236_52
# 23816
# A0A0G2JYC6_491
# 23817
# Q02790_179
# 23818
# B2GV24_632
# 23819
# O75223_101
# 23820
# Q5RJR8_172
# 23821
# Q06000_4
# 23822
# Q8IWA4_352
# 23823
# Q9JLA3_1309
# 23824
# Q13813_2047
# 23825
# D4AD15_1038
# 23826
# B2RYG6_122
# 23827
# P14735_933
# 23828
# P46844_91
# 23829
# Q1JU68_23
# 23830
# P40227_430
# 23831
# Q09666_5765
# 23832
# P25409_105
# 23833
# G3V628_90
# 23834
# A0A0G2JUC7_366
# 23835
# P56741_313
# 23836
# A0A0G2JUP3_3717
# 23837
# M0R4P2_132
# 23838
# Q99376_225
# 23839
# P00505_107
# 23840
# Q96CS3_146
# 23841
# Q96E11_105
# 23842
# F1LQP9_285
# 23843
# Q309B1_114
# 23844
# Q70UQ0_281
# 23845
# Q8TDD1_109
# 23846
# P53804_589
# 23847
# D4A8G7_213
# 23848
# Q02818_136
# 23849
# A0A0G2K1W9_335
# 23850
# Q15067_260
# 23851
# Q6PGP7_1391
# 23852
# Q86VQ0_177
# 23853
# Q14839_266
# 23854
# P49792_2272
# 23855
# Q14244_600
# 23856
# Q9UNH7_60
# 23857
# P04406_107
# 23858
# Q8WZ42_18292
# 23859
# Q92538_760
# 23860
# Q02952_1429
# 23861
# O43847_57
# 23862
# D3ZWJ2_299
# 23863
# F1LNF0_1783
# 23864
# P55072_164
# 23865
# F1LQT3_1162
# 23866
# P27708_2003
# 23867
# Q9H583_1066
# 23868
# A0A0G2K6B7_596
# 23869
# Q15431_718
# 23870
# Q9BZE4_347
# 23871
# Q04462_432
# 23872
# Q9NQ48_187
# 23873
# Q9Z220_277
# 23874
# Q96EK6_135
# 23875
# Q62824_292
# 23876
# O75150_921
# 23877
# Q8WZ42_13988
# 23878
# Q924S5_678
# 23879
# Q6TXF6_147
# 23880
# Q07157_191
# 23881
# D3ZMY7_313
# 23882
# P14209_74
# 23883
# A0A0G2JY08_1660
# 23884
# Q66H91_692
# 23885
# Q8N9T8_329
# 23886
# D4A3X0_571
# 23887
# Q9BRJ6_3
# 23888
# Q7L576_503
# 23889
# Q09666_903
# 23890
# Q8TCT9_251
# 23891
# P05023_9
# 23892
# P41542_710
# 23893
# Q13428_405
# 23894
# G3V6A8_2740
# 23895
# Q13813_1952
# 23896
# Q8TEQ6_419
# 23897
# Q9NVA2_195
# 23898
# P50398_79
# 23899
# A0A0G2K0I3_317
# 23900
# P30622_70
# 23901
# Q99613_745
# 23902
# Q6P2Q9_1570
# 23903
# Q8IVF2_1599
# 23904
# Q14CX7_832
# 23905
# Q9NP61_339
# 23906
# B2RYN0_8
# 23907
# D3ZCL8_1164
# 23908
# Q969G3_255
# 23909
# Q68FX9_28
# 23910
# A0A0G2JSK1_187
# 23911
# O75352_39
# 23912
# D4A9G1_5
# 23913
# Q14839_127
# 23914
# Q5BKZ1_255
# 23915
# Q7L014_793
# 23916
# Q9P287_6
# 23917
# A0A0G2K1X6_1790
# 23918
# Q8N2F6_333
# 23919
# Q96CW1_11
# 23920
# P12081_37
# 23921
# Q14651_543
# 23922
# Q14157_612
# 23923
# Q08378_1163
# 23924

# %%
#storagegpsfeatures('E:/NingLab/object/khib/results/', namelist, gpn, 0)
